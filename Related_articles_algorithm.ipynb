# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/keywords.csv")
data['keywords']
# Out:
# 0       parabolic-hyperbolic_type Gerasimov–Caputo_der...
# 1       rearrangement_invariant_spaces Hardy_classes g...
# 2       boundary_value_problem Fourier_series eigenval...
# 3       Schrödinger_type_equation the_Caputo_derivativ...
# 4       problem_with_parameter second_order_system_of_...
#                               ...
# 1695    Generalised_derivation Matrix_and_operator_equ...
# 1696    Harmonic_univalent_starlike_functions Dziok-Sr...
# 1697    Almost_sure_limit_theorems random_allocations ...
# 1698    L1-convergence Dirichlet_kernel monotone_decre...
# 1699     Determinant LU-decomposition Recurrence_relation
# Name: keywords, Length: 1700, dtype: object

# %%
doc = []
for line in data['keywords']:
  for word in line.split(' '):
    if len(word) > 3 and line not in doc:
      doc.append(line)
doc
# Out:
# ['parabolic-hyperbolic_type Gerasimov–Caputo_derivatives discontinuous_gluing_condition integral_equations',
#  'rearrangement_invariant_spaces Hardy_classes grand-Lebesgue_spaces the_Orlicz_spaces Boyd_indices',
#  'boundary_value_problem Fourier_series eigenvalues eigenfunctions uniqueness_of_a_solution existence_of_a_solution',
#  'Schrödinger_type_equation the_Caputo_derivatives time-dependent_source_identification_problem',
#  'problem_with_parameter second_order_system_of_hyperbolic_equations Goursat_problem solvability algorithm',
#  'biharmonic_map triharmonic_map conformal_deformation',
#  'trigonometric_series absolute_summability measuring_set coefficient function',
#  'unit_graph traversability clique_number independent_number covering_number',
#  'two-body_Hamiltonian Schrödinger_operators Fridrix’s_model eigenvalue essential_spectrum asymptotics_of_the_Fredholm_determinant',
#  'operator_norm spectral_radius numerical_radius',
#  'acoustic_wave liquid_droplet vapor–gas_bubble viscoelastic_shell heat_and_mass_transfer',
#  'hydrodynamics lattice_Boltzmann_method',
#  'Gauss_hypergeometric_function hypergeometric_functions_of_three_variables analytical_continuation_formulas integral_representations',
#  'de_Sitter_3-space Geodesic Magnetic_field Magnetic_trajectory Hyperbolic_quaternion Killing_vector_field',
#  'mathematical_model_filtration dilation swelling disjoining_pressure',
#  '(pure-)injective_modules (pure-)C2_modules (von_Neumann)_regular_rings (pure-)semisimple_rings',
#  'model_calibration MLE transition_densities heat_kernels range-based_estimators algorithmic_trading',
#  'authentication_protocols processes verification',
#  'associative_steganography coverage_completeness_criterion carrier_size_reduction brute-force_attack_resistance steganographic_durability interference_immunity',
#  'Marshall–Olkin_distribution sine–G_family Exponential_distribution Maximum_likelihood_estimation',
#  'neural_computing neural_turing_machine differential_neural_computer algorithm_complexity',
#  'singular_coefficient uniqueness_of_a_solution existence_of_a_solution singular_integral_equation Wiener–Hopf_equation index_of_equation residue',
#  'optimal_quadrature_formulas the_extremal_function Sobolev_space optimal_coefficients Cauchy_type_singular_integral weight_function singular_integral_equation',
#  'singularity_segment partial_differential_equation_of_parabolic_type bisingularly_problem singular_perturbed asymptotic method_of_boundary_layer_function first_boundary_value_problem small_parameter',
#  'adaptive_mesh lattice_Boltzmann_method Cuda MPI',
#  'averaging_method periodic_solution non-integrability',
#  'parabolic_type Fenchel–Nielsen_parameters zero-twist_tight_flute_surface Loch_Ness_monster',
#  'slow-fast_Hamiltonian_system averaging_method normal_form_theory integrable_model improved_first_integral',
#  'Wagner_lift minimal_surfaces constant_mean_curvature_surfaces sectional_curvature',
#  'group_bundle Lie_groupoid Ehresmann_connection differential_algebraic_group Ambrose–Singer_theorem',
#  'harmonic_functions Liouville’s_theorem',
#  'axial_principal_lines axial_mean_lines principal_axial_cycle axiumbilic_point',
#  'curvature_line umbilic_point compact_surface',
#  'complex_analytic_vector_fields first_integrals essential_singularities',
#  'Frobenius_manifolds Frobenius_algebras manifolds_over_algebras coalgebras',
#  'traveling_wave_solution degenerate_reaction–diffusion_equations Fisher–KPP_equation FitzHugh–Nagumo_system sharp_fronts',
#  'principal_lines principal_line_fields partially_umbilic_point principal_configuration',
#  'Fredholm_integro-differential_equations weakly_singular_kernel two-point_boundary_value_problem Fredholm_integral_equations algorithm unique_solvability',
#  'minimal_time integral_equation boundary_control initial-boundary_problem admissible_control',
#  'Neumann_problem multidimensional_elliptic_equations_with_several_singular_coefficients Lauricella_hypergeometric_function_of_many_variables adjacent_and_limiting_relations multidimensional_improper_integrals',
#  'two-phase_medium_dynamics symmetry_analysis group_classification invariant_solution',
#  'degenerate_ordinary_differential_equation boundary_value_problem existence uniqueness partial_differential_equation_not_solved_for_the_derivative',
#  'boundary_value_problem degenerate_equation parabolic-hyperbolic_type Gaussian_hypergeometric_function Cauchy_problem existence_and_uniqueness_of_the_solution method_of_integral_equations fractional_Gerasimov–Caputo_derivative',
#  'differential_game life_line pursuit evasion strategy geometric_constraint',
#  'involution nonlocal_operator parabolic_equation spectral_problem completeness eigenfunction Le_Roy_function Hadamard–Caputo_operator',
#  'Hilfer_type_fractional_equation nonlinear_differential_equation mixed_problem single-value_solvability method_of_successive_approximations',
#  'dynamic_system Andronov–Hopf_bifurcation Lyapunov_quantities transcriticity equilibrium_point stability reaction–diffusion_equation cubic_nonlinearity',
#  'differential_equations_with_impulses periodicity the_critical_case_of_stability Andronov–Hopf__bifurcation',
#  'problem_with_conditions_on_the_characteristics system_of_hyperbolic_equation_with_piecewise-constant_argument_of_generalized_type family_of_boundary_value_problems new_general_solution solvability',
#  'potential_operator direct_variational_formulation variational_principle Hamilton–Ostrogradskii_equations',
#  'three-dimensional_Tricomi_equations linear_inverse_problem_with_a_semi-nonlocal_boundary_condition problem_correctness ‘‘\\(\\varepsilon\\)-regularization’’_method a_priori_estimation_method approximation_sequences_method Fourier_transforms',
#  'hyperbolic_equation_with_two_lines_of_degeneracy_of_the_second_kind expansion_formula_for_the_Pochhammer_symbol Appell_hypergeometric_function generalized_solution Cauchy_problem',
#  'Banach_spaces Fredholm_operator generalized_solution fundamental_operator_function',
#  'degenerate_type_equations linearly_independent_solutions generalized_hypergeometric_function Euler–Bernoulli_equation exact_solutions',
#  'Implicit_Volterra_integro-differential_equation_of_the_first_order weak_nonlinearity estimate_of_solutions asymptotic_smallness_of_solutions',
#  'mixed_type_equation nonlocal_equations equation_with_degeneration nonlocal_problem integro-differentiation_operator the_Kilbas–Saigo_function Fourier_series',
#  'Burgers_equation degenerating_domain dynamic_boundary_condition a_priori_estimate',
#  'essentially_loaded_differential_equation impulse_effect parametrization_method algorithm',
#  'symptotics hyperbolic_operator mixed_boundary_condition',
#  'singularly_perturbed_system parabolic_equations boundary_layer',
#  'partial_differential_equations pseudoparabolic_equation_of_fourth-order semi-periodic_boundary_value_problem algorithm approximate_solution',
#  'heat_equation degenerating_domain Laplace_transform Green’s_function Fourier_method',
#  'equation_of_mixed_type degeneration_of_power_type inverse_problem uniqueness_criterion series existence stability',
#  'nonlinear_differential_equation point_symmetries exact_solutions',
#  'Gerasimov–Caputo_fractional_derivative Wright_function Mittag-Leffler_function Dirac_delta_function integral_equation',
#  'Benney–Luke_type_differential_equation nonlinear_integral_conditions Fourier_method absolute_and_uniform_convergence regular_solvability',
#  'Hamiltonian_system stability multiplier small_parameter parametric_resonance',
#  'integro-differential_equation non-model_equation characteristic_equation two-point_special_differential_operator unique_solvability',
#  'thermoviscoelastic_fluid alpha-model Voigt_fluid existence_theorem topological_degree',
#  'Lyapunov_function energy_function diffeomorphism surface',
#  'orbifold Anosov_diffeomorphism Anosov_action Loretzian_metric isometry_group',
#  'periodic_solutions exponential_dichotomy projectors Lyapunov_equation Sobolev_spaces',
#  'synchronization chaos quadratic_Lyapunov_functions frequency-domain_analysis',
#  'attractor diffeomorphism homoclinic_orbit bifurcation',
#  'homoclinic_orbit Van_der_Pol–Duffing_oscillator Shilnikov_chaos',
#  'diffeomorphism 3-dimensional_manifold expanding_attractor embedding_of_frames',
#  'Lorenz_system homoclinic_orbits periodic_motions Lorenz_attractors',
#  'essentially_nonlinear_differential_equations locally_integral_manifolds invariant_foliation logarithmic_norms stability',
#  'Lorenz_attractor pseudohyperbolicity Lyapunov_exponents wild_hyperbolic_set',
#  'nonlinear_parabolic_equations_with_involution_in_the_spatial_variable metastable_structures center_manifold_method Galerkin_approximation_of_approximate_solutions',
#  'population_dynamics two-predators-one-prey_model bimodal_smooth_maps Schwarzian_derivative period_doubling_bifurcations bistability',
#  'differential_equation_of_neutral_type variable_coefficients time-varying_delay estimates_for_solutions stability Lyapunov–Krasovskii_functional',
#  'model_of_immune_response_in_plants delay_differential_equations asymptotic_stability estimates_of_solutions attraction_set Lyapunov–Krasovskii_functional',
#  'periodic_differential_operators homogenization operator_error_estimates hyperbolic_equations',
#  'two-dimensional_diffeomorphisms nontransverse_homoclinic_points stable_periodic_points characteristic_exponents',
#  'pandemic_uncertainty vaccination self-isolation COVID-19',
#  'exponential_stability Lyapunov–Krasovskii_functional distributed_delay neutral_type_equation estimates_of_solutions',
#  'system_reliability moving_extreme_ranked_set_sampling minimax_ranked_set_sampling exponential_distribution relative_efficiency ranking_errors',
#  'strong_law_of_large_numbers Hilbert_space blockwise_pairwise_and_coordinatewise_negative_dependence',
#  'Poisson-weighted_exponential_distribution zero-truncated_distribution maximum_likelihood_estimation',
#  '\\(\\lambda\\)-statistical_monotone',
#  '\\(\\lambda\\)-statistical_order_convergence statistical_convergence Riesz_space order_convergence',
#  'zero-truncated_distribution mixed_negative_binomial_distribution count_data maximum_likelihood_estimation',
#  'mixed_negative_binomial_distribution negative_binomial_weighted_Lindley_distribution over-dispersion parameter_estimation',
#  'discrepancy lacunary_sequence law_of_the_iterated_logarithm',
#  'negative-binomial_random_sums Zolotarev’s_probability_metric rate_of_convergence weak_limit_theorem',
#  'geometric_distribution first_success_distribution maximum_likelihood_estimation_method',
#  'combined_estimators bias mean_square_error simple_random_sampling',
#  'community_detection weighted_networks Bayesian_nonparametrics mixture_models spectral_methods',
#  'positive_contraction',
#  '\\(P\\)-completely_mixing Markov_operator uniform_ergodicity Dobrushin_ergodicity_coefficient',
#  'Bayesian_estimation frailty generalized_Lindley_frailty hazard_rate MCMC random_censoring Weibull_distribution',
#  'coefficient_of_variation power_of_the_test type_I_error_rates',
#  'Bayesian_method bonus-malus_system number_of_claims claim_size randomized_neighborhood_search',
#  'statistical_modeling normal_distribution truncated_normal_distribution Weibull_distribution goodness_of_fit chi-square_test Kolmogorov–Smirnov_test AIC BIC wind_load',
#  'indigenous_artifacts archaeology clustering statistical_analysis carbon_dating',
#  'negative_binomial_distribution Lindley_distribution cure_rate_model survival_analysis lifetime_distribution',
#  'zero-truncated weighted_Lindley_distribution maximum_likelihood_estimation simulation_procedures application',
#  'length–biased Weibull–Rayleigh_distribution maximum_likelihood_estimation hydrological_data',
#  'artificial_bee_colony_(ABC)_algorithm economic-statistical_design;_Hotelling’s_\\(T^{2}\\)',
#  'Monte_Carlo_method multivariate_Bayesian_control_chart variable_sample_size',
#  'non_response auxiliary_variable exponential_type_estimators efficiency mean_square_error',
#  'estimators simple_random_sampling mean_square_error auxiliary_variable study_variable',
#  'auxiliary_variable main_variable estimator Searls_technique',
#  'competing_risks random_censoring likelihood_ratio_statistics local_asymptotical_normality uniform_asymptotical_normality asymptotic_efficiency',
#  'Fredholm_integro-differential_equations problem_with_integral_condition parameter degenerate_kernel unique_solvability',
#  'accretive_differential_operator self_adjoint_differential_operator deficiency_index space_of_boundary_values spectrum',
#  'mixed-type_equation fractional_derivative_in_the_sense_of_Gerasimov–Caputo inverse_problem determination_the_orders_of_fractional_derivative one_value_solvability',
#  'von_Neumann_algebra algebra_of_measurable_operators ring_isomorphisms real_algebra_isomorphism real_\\(\\ast\\)-isomorphism',
#  'm-degrees 1-degrees',
#  'hyperspace',
#  '\\(\\aleph\\)-space finally_compact_space extremally_disconnected_space uniform_space uniformly_connected uniformly_paracompact uniformly_\\(R\\)-paracompact',
#  '2-cone_normed_space_over_the_Banach_algebra solid_cone fixed_point',
#  'Gauss_hypergeometric_function Integral_representation Runckel’s_theorem',
#  'branching_random_processes transient_phenomena numerical_characteristics generating_functions estimates_of_the_rate_of_convergence branching_processes_close_to_critical_ones',
#  'main_variational_problem Euler_problem reinforced_Legendre_condition Jacobi_equation Steklov_inequality sufficient_condition_of_extremum',
#  'forced_oscillations bubbly_liquid cylindrical_path amplitude_and_phase_frequency_characteristics',
#  'cubic_stochastic_operator Volterra_operator non-Volterra_operator trajectory',
#  'model three-layered_rod loss_in_stability middle_layer bending_a_beam numerical_experiment',
#  'conformal_radius pre-Schwarzian_derivative subordination convex_function starlike_function Miller–Mocanu_operator Biernacki-type_operator Gakhov_equation',
#  'balayage_of_measure polynomial logarithmic_potential subharmonic_function Riesz_measure Weierstrass–Hadamard_representation polar_set',
#  'multi_criteria_optimization optimality_criteria parameter_analysis_of_stability kinetic_model catalytic_reaction',
#  'non-alternating_Hamiltonian_Lie_algebra non-alternating_Hamiltonian_form characteristic_two',
#  'loaded_equation Caputo_fractional_derivative heat_equation Volterra_integral_equation',
#  'cubic_stochastic_operator Volterra_operator non-Volterra_operator regular_and_non-regular_operator',
#  'mean_field_game time-fractional_derivative non-convex_optimization coefficient_control finite_difference_method stability_estimates',
#  'group_algebra classical_ring_of_fractions centrally_essential_ring',
#  'conformal_modulus doubly_connected_domain quadrilateral quasiconformal_mapping convergence_of_domains_to_a_kernel',
#  'decomposition decidability computational_complexity',
#  'boundary_value_problem_of_heat_conduction singular_Volterra_integral_equation Bessel_function Carleman–Vekua_regularization_method solvability',
#  'Riemann_boundary_value_problem Picard–Privalov_alternatives',
#  'Fejer_sum class_of_Poisson_integrals asymptotic_inequality',
#  'Differential_game Langenhop_type_constraint geometric_constraint integral_constraint pursuit evasion strategy',
#  'gas_cavities grid-characteristic_method structured_grids numerical_modelling',
#  'family_of_theories rank degree',
#  '\\(E\\)-closure',
#  '\\(e\\)-spectrum',
#  'boundary_value_problem finite_element_method piecewise_linear_approximation Dealaunay_triangulation recursive_algorithm',
#  'normal_distribution flexibility_of_distribution departure_from_normality random_number_generator maximum_likelihood_estimator Monte_Carlo_method',
#  'Laurent_series_ring right_semidistributive_ring semilocal_ring',
#  'inverse_problem involution nonlocal_operator parabolic_equation Fourier_method spectral_problem completeness eigenfunction',
#  'turning_point inner_layer singular_perturbed asymptotic method_of_boundary_layer_function two_point_problem small_parameter ordinary_differential_equation',
#  'system_of_loaded_integro-differential_equations involutory_transformation boundary_value_problem Cauchy_problem parametrization_method unique_solvability degenerate_kernel',
#  'analytic_functions harmonic_function quasiconformal_mapping Bohr’s_inequality subordination_and_quasisubordination',
#  'caliber subtle_superextension weight Souslin_number subtle_complete_coupled_systems',
#  'absolute_permeability heterogeneity anisotropy porous_media tortuosity Kozeny–Carman_equation lattice_Boltzmann_equations',
#  'National_Research_Computer_Network network_operations_center network_management FCAPS eTOM ITIL network_monitoring_and_control network_services software_solutions',
#  'National_Research_Computer_Network_of_Russia NIKS National_Research_and_Education_Network NRENs R&E_community service_platform GÉANT supranational_services identity_federation eduGAIN eduroam',
#  'supercomputers high_performance_computing parallel_programs_profiling external_memory I/O_operations',
#  'nonlinear_equations shallow-water_icing_model bisection_method Newton’s_method Brent’s_method',
#  'supercomputer high_performance_computing job_management_system supercomputer_job_scheduling simulation_accuracy SUPPZ Alea',
#  'digital_project directed_acyclic_graph internet_platform software_platform cloud_services high_performance_computing',
#  'AMG setup_cost_amortization non-steady_state reuse_strategies',
#  'innovation novelty demand implementability additive_criterion utility_function additive_independence partial_criterion',
#  'erosion deposition porous_media experiment mathematical_model GPU_computations',
#  'supercomputer energy_efficiency power_consumption_profile parallel_program high_performance_computing_system HPC NAS_Parallel_Benchmarks Intel',
#  'supercomputer high_performance_computing job_management_system supercomputer_job_scheduling job_runtime_prediction SUPPZ',
#  'supercomputer unstructured_surface_computational_mesh decomposition domain high-performance_computing scaling_of_calculations',
#  'knots colored_Jones_polynomial asymptotics_of_solutions_to_a_\\(q\\)-recurrence_equation',
#  'Lagrangian_system oscillations amplitude control optimization',
#  'coherent_state commutation_relations non-orthogonal_unite_decomposition',
#  'pressureless_gas strong_singularities concentration decay Rankine-Hugoniot_relations',
#  'numerical_analysis_and_simulation fluid_dynamics mechanics_of_particles_and_systems multicomponent_multiphase_fluid_flow multiscale_approach natural_gas_purification chemisorption adsorption-catalytic_process',
#  'logic_circuit self-correction unreliable_gate Boolean_function',
#  'systems_of_conservation_laws singularities Rankine–Hugoniot_relations variational_representation weak_solutions neural_networks',
#  'Meixner_polynomials Hermite–Padé_approximants equilibrium_problems_for_logarithmic_potentials',
#  'read-once_formula finite_field polynomial three-valued_logic distribution_of_values',
#  'wave_equation transparent_boundary_conditions solution_in_circular_channel waveguide Padé_approximation',
#  'Hilbert_space linear_operator von_Neumann_algebra',
#  '\\(C^{*}\\)-algebra weight trace tracial_inequality',
#  'quantum_error_correction non-commutative_operator_graph qubit quantum_oscillator quantum_anticlique POVM',
#  'quantum_state_discrimination quantum_cryptography heterodyne_measurement',
#  'category_of_monoids category_of_compact_right_topological_monoids coproduct exact_sequence_of_monoids extension_of_monoids forgetful_functor left_adjoint_functor Stone–Čech_compactification_functor',
#  'Hilbert_space linear_operator projection von_Neumann_algebra tracial_state independence',
#  'discrete_dynamical_system geometrically_integrable_map invariant_set periodic_orbit coexistence_of_periods_of_periodic_orbits',
#  'poset_of_partial_isometries',
#  '\\(\\ast\\)-order',
#  '\\(\\ast\\)-orthogonality',
#  'quadratic_map gradient',
#  '\\(\\text{K3}\\)_surface',
#  'Random_field Gibbs_random_field correlation_functions specification P-function Q-function',
#  'free_product_of_algebras commutator_relation mutually_unbiased_bases abelianization',
#  'learning_theory statistical_mechanics evolution_theory functional_programming',
#  'dynamical_behavior_of_stochastic_systems classification_problem diagnostics qubit_system quantum_system Markovian_process',
#  'quantum_measurement_channel classical_capacity entanglement-assisted_capacity',
#  'reduced_semigroup_\\(C^{*}\\)-algebra free_Banach_module graded_\\(C^{*}\\)-algebra cyclic_Banach_module topological_isomorphism_of_Banach_modules',
#  'quantum_technologies distributed_system_with_diffusion quantum_control laser-assisted_isotope_separation molybdenum_isotopes',
#  'open_quantum_system two_qubits optimal_quantum_control coherent_control incoherent_control',
#  'random_linear_operator random_operator_valued_process law_of_large_numbers central_limit_theorem',
#  'Gibbs_process uniqueness Kirkwood–Salsburg_equations',
#  'spectral_decomposition_of_a_state quantum_channel Holevo_capacity output_entropy entropy_exchange mutual_information coherent_information squashed_entanglement_of_a_channel',
#  'open_quantum_system master_equation Markovianity rotating_wave_approximation',
#  'inverse_problem nonlinear_filtration bottomhole_pressure well_testing stress_sensitive_fractured_porous_reservoir pressure_dependent_permeability',
#  'dynamics_of_gas_bubbles cluster_of_bubbles hydrodynamic_interaction_of_bubbles radial_oscillations_of_bubbles particle_model_of_bubble_interaction',
#  'unsteady_heat_transfer enclosing_structures radiation-convective_heat_transfer numerical_methods computer_simulation',
#  'inverse_problem Navier–Stokes_equations RANS-methods high-lift_devices multi-element_airfoil target_pressure_distribution',
#  'harmonic_oscillations circular_cylinder steady_streaming viscous_incompressible_fluid asymptotic_expansions',
#  'three-phase_flow inverse_problem permeability_identification',
#  'waves bubbly_liquid heat_and_mass_transfer',
#  'airfoil flap/slat_systems Fowler_flap neural_net',
#  'radial_oscillations gas_bubbles viscoelastic_shell_and_liquid Maxwell’s_model Kelvin–Voigt_model',
#  'thermoacoustic_waves heat_transfer natural_convection finite-volume_method',
#  'resonance nonlinear_gas_oscillations closed_tube',
#  'acoustic_wave reflection_coefficient polydisperse_inclusions',
#  'liquid_drop_impingement curved_solid_surface shock_wave initial_jetless_stage',
#  'porous_medium self-similar_solution phase_transition extended_area_of_gas_hydrate_formation',
#  'cavitation_bubble ultrasound_excitation bubble_collapse_near_a_wall cumulative_liquid_jet boundary_element_method',
#  'bubble_dynamics boundary_element_method boundary_integral_equation_method',
#  'continuos_system Lipschitz_condition uncertain_disturbances discrete_measurements observer_design',
#  'oblate_ellipsoidal_shell bending temperature limit_load axisymmetric_load',
#  'Couette–Taylor–Poiseuille_flow torque numerical_simulation two-phase_flow annular_channel',
#  'downhole_heater radial_fluid_flow reservoir_temperature thermal_dispersion Peclet_number well_productivity',
#  'gas_hydrates mathematical_model algorithm sampling',
#  'filtration numerical_solution formation_of_gas_hydrate zonal_heterogeneous_porous_reservoir',
#  'Orr–Sommerfeld_equation thermoviscous_fluid eigenvalues eigenfunctions Reynolds_number aqueous_solution_of_propylene_glycol heat-exchanger',
#  'plane cylindrical_and_spherical_waves longitudinal_and_transverse_waves porous_media capillary_pressure three_phase_fluid',
#  'gas_suspension acoustic_waves impedance reflection_coefficient refraction_coefficient',
#  'acoustic_cavitation bubble_dynamics bubble_collapse converging_shock_waves',
#  'multiphase_nonisothermal_flow decomposition_methods high_performance_computing',
#  'quasi-hydrostatic_approximation atmospheric_modelling linear_instability shortwave_perturbation pseudo_viscosity',
#  'a_toroidal_shell a_local_deepening_on_the_inner_surface a_spline_option_of_the_finite_element_method stress_intensity',
#  'three-dimensional_finite_elements two-dimensional_finite_elements complex_geometry parametrization',
#  'incompressible_flow bifurcation_theory homotopy_method stability nonlinearity gradient_fluid',
#  'nonlinear_partial_equations Sobolev-type_equations exact_solutions',
#  'ontology_design word2vec semantic_relationships subject_ontology',
#  'space–time_continuum variational_models non-integrable_variational_forms irreversible_processes coupled_hydrodynamics_and_heat_transfer Darcy_equations Brinkman_equations',
#  'data_assimilation_problem DA_problem generalized_Kalman_filter_method Ornstein–Uhlenbeck_process',
#  'fading_channels multiple-wave_with_diffuse_power_(MWDP) two_wave_with_diffuse_power_(TWDP)',
#  '\\(\\mathcal{B}\\)-function special_functions hypergeometric_functions Lauricella_hypergeometric_function bit_error_rate',
#  'problem_of_Sturm–Liuvill second_order_differential_equations equations_with_variable_coefficients integral_formulas',
#  'heat_equation spectral_problem',
#  'thermoelasticity thermal_conductivity coupled_effects generalized_Papkovich–Neuber_representation fundamental_solutions',
#  'incompatible_deformations residual_stresses body_manifold non-Euclidean_geometry material_connections Cartan_moving_frame curvature torsion nonmetricity contorsion surface_growth',
#  'biharmonic_operator boundary_value_problems scattering_model variational_method',
#  'biharmonic_operator Steklov_and_Steklov-type_boundary_conditions Dirichlet_integral weighted_spaces',
#  'micropolar_theory theory_of_thin_bodies Legendre_and_Chebyshev_polynomials multilayer_thin_body tensor-operator_of_stress_and_couple_stress tensor-block_matrix_operator decomposition_of_initial-boundary_value_problems',
#  '3D_printing selective_laser_melting additive_manufacturing concentrated_load moving_load heat_flux transient_function',
#  'semantic_library subject_domain ontology thesaurus data_integration data_preprocessing data_cleaning data_model',
#  'electroelasticity surface_shear_wave gradient_effects attenuation',
#  'gradient_elasticity Papkovich–Neuber_representation fourth-order_equations fundamental_solutions_of_Laplace_and_Helmholtz_equations Green’s_integral_formula Trefftz_method Bubnov–Galerkin_projection_method',
#  'cavitation_bubble_dynamics bubble_collapse non-spherical_bubble convergent_shock_waves non-spherical_shock_waves wide-range_equations_of_state direct_numerical_simulation Godunov_method',
#  'filtration gas_hydrate methane carbon_dioxide replacement mathematical_modeling',
#  'cavitational_flows nonlinear_functional global_minimization',
#  'porous_medium layer waveguide wave_propagation',
#  'boundary_value_problem circular_plate boundary_conditions average_pressure linear_bending nonlinear_bending',
#  'circular_cylinder cross_flow channel vortical_patterns_in_wake direct_numerical_simulation Fourier_transform transition_to_turbulence spectral_analysis',
#  'elasticity creep plasticity viscosity thermal_conductivity large_strains',
#  'fiber_reinforced_plastic fiber bundle_of_fibers epoxy specimen cross-ply_lay-up tension compression shear linearized_equations buckling_modes finite_sum_method integrating_matrices ultimate_stress',
#  'multilayer_plate discrete_structural_model internal_friction_of_the_material Kelvin–Voigt_model generalized_Helmholtz_equation free_and_forced_vibrations complex_vibration_frequency sound_insulation_parameter sound_pressure',
#  'oil_reservoir well_patterns two-phase_flow viscosity_ratio fixed_streamtube_model low-dimensional_problems high-speed_models high-resolution_models',
#  'orthotropic_materials integration_of_equations_equilibrium displacements stresses',
#  'mathematical_modeling finite_deformations constitutive_equations phase_transition relaxation_transition shape_memory boundary_value_problems finite_element_method',
#  'multiplicative_decomposition_of_deformation_gradient_tensor rigid_moving_coordinate_system constitutive_mathematical_models geometrical_nonlinearity',
#  'large_elastoplastic_deformations contact_interaction',
#  'elastic_diffusion coupled_problem unsteady_problem integral_transform multicomponent_continuum Kirchhoff–Love_plate Green’s_function',
#  'work-stealing_balancers work-stealing_deques data_structures absorbing_Markov_chains random_walks',
#  'AlgoWiki problems methods algorithms implementations information_graph parallel_structure supercomputer',
#  'global_optimization non-convex_constraints mixed-integer_problems local_tuning parallel_algorithms',
#  'ultrasound_tomography wave_simulation multi-core_processor GPU',
#  'thin_films molecular_dynamics silicon_dioxide_films laser_pulses heat_transfer stresses laser_induced_damage',
#  'dark_states supercomputer Tavis–Cummings_model graph_algorithms',
#  'thesaurus embedding lexical_relations senses',
#  'supercomputing high-performance_computing workload_analysis efficiency data_analysis monitoring_data system_software',
#  'high-performance_computing parallel_computing performance_analysis performance_variability supercomputers',
#  'drug_discovery docking quantum_chemistry inhibitors PLpro SARS-CoV-2 COVID-19 CADD',
#  'large-eddy_simulation subgrid_models boundary_layer_turbulence evening_transition computational_performance',
#  'hpc mpi parallel clustering error_messages',
#  'multidimensional_integration multivariate_integration numerical_integration sampling_point tensor_train TT-format',
#  'open_quantum_systems integer_programming machine_learning',
#  'differential_equation fractional_de-_rivative fractional_Caputo_derivative stability uniform_convergence_of_a_locally_one-dimensional_difference_scheme convection-diffusion_equation locally_one-dimensional_scheme',
#  'parabolic_variational_inequality obstacle_problem penalty_method regularization_method accuracy_estimate',
#  'numerical_simulation elastic_waves grid-characteristic_method discontinuous_Galerkin_method unstructured_grids regular_grids',
#  'scientific_computing non-uniform_grid difference_maximum_principle monotone_difference_scheme regularization_principle convection-diffusion_equation third_boundary_value_problem two-side_estimate',
#  'symmetric_linear_multistep_methods periodical_initial_value_problem stability_polynomial interval_of_periodicity',
#  'mean_field_games additional_inequality Fokker–Planck–Kolmogorov_equation Hamilton–Jacobi–Bellman_equation discrete_approximation numerical_solution',
#  'eigenvibration bar mechanical_resonator eigenvalue eigenfunction eigenvalue_problem ordinary_differential_equation finite_element_method',
#  'quasilinear_parabolic_problem time-fractional_derivative regularized_scheme stability accuracy',
#  'circular_cylinder cross_flow channel gap_between_cylinder_and_wall large-scale_vortex transition_to_turbulence spiral_tornado-like_motion',
#  'machine_learning convolutional_neural_networks mathematical_modeling grid-characteristic_method exploration_seismology inverse_problems fractured_media',
#  'modified_ramsey_model consumer_behavior mean_field_games optimal_control numerical_solution',
#  'Schwartz_algebra entire_function slowly_decreasing_function distribution_of_zero_set',
#  'Hilbert_spaces entire_functions unconditional_bases reproducing_kernels',
#  'Sturm–Liouville_equation trivial_monodromy spectral_instability spectrum_localization',
#  'meromorphic_function Nevanlinna_characteristic subharmonic_function',
#  '\\(\\delta\\)-subharmonic_function Riesz_measure',
#  'Series_of_exponential_monomials weight_space analytic_continuation condensation_index',
#  'differential_operators closed_sets time_scales inverse_spectral_problems',
#  'Liouville_lattice soliton breather instanton linear_spectrum homoclinic_orbit periodic_solutions C-integrability',
#  'elliptic_pseudo-differential_equation boundary_value_problem singular_domain asymptotic_behavior',
#  'family_of_boundary_value_problems integro-differential_equations_of_mixed_type parametrization_method solvability',
#  'degenerate_fractional_optimal_control_problem initial_value_problem Caputo_fractional_derivative Lebesgue_spaces Pontryagin’s_maximum_principle',
#  'inhomogeneous_chain_of_harmonic_oscillators Cauchy_problem random_initial_data space-time_statistical_solutions weak_convergence_of_measures',
#  'anomalous_diffusion integro-differential_equation Gerasimov–Caputo_fractional_derivative Laplace_transform Fourier_transform convolution_theorem explicit_solution',
#  'parabolic-hyperbolic_type_equation integral_condition Cauchy_problem first_boundary_value_problem',
#  'discrete_bilaplacian eigenvalue asymptotics essential_spectrum',
#  'discrete_Schrödinger_operator quasi-momentum essential_spectrum eigenvalue determinant',
#  'three_body_Hamiltonian discrete_Schrödinger_operator short-range_pair_potentials eigenvalues essential_spectrum',
#  'boundary_value_problem third-order_partial_integro-differential_equation existence_and_uniqueness_of_solution degenerate_kernel multiple_characteristics Green’s_function',
#  'infinite_waveguide metal_diaphragm rectangular_resonator eigen_frequency',
#  'diffraction_problem method_of_moments CUDA_technology RWG_functions',
#  'antenna chiral_metamaterial hypersingularity method_integral_equations current_density',
#  'electromagnetic_wave_diffraction integral_equations collocation_method Chebyshev_polynomials',
#  'boundary_integral_equations numerical_methods computational_electrodynamics mathematical_modeling_of_antennas',
#  'electromagnetic_wave scattering axial-symmetric_body non-coordinate_boundary',
#  'electromagnetic_wave diffraction generalized_function',
#  'lasing_eigenvalue_problem set_of_Muller_boundary_integral_equations',
#  'nonstationary_electrodynamics integral_equations media_without_dispersion effective_algorithms',
#  'non-polarized_electromagnetic_waves inhomogeneous_waveguide complex_permittivity dielectric_with_losses non-linear_eigenvalue_problem Maxwell_equations operator-function spectrum',
#  'equation_of_mixed_parabolic-hyperbolic_type inverse_problem uniqueness series small_denominators existence',
#  'surface_wave dielectric_layer inhomogeneous_layer eigenvalue_problem Maxwell’s_equations operator_pencil spectrum double_completeness',
#  'non-polarized_electromagnetic_waves anisotropic_waveguide non-linear_eigenvalue_problem Maxwell’s_equations operator-function spectrum',
#  'fluid_filtration Darcy–Brinkman_law Integral_equations Potential_theory Piecewise-constant_approximation Collocation_method',
#  'orthogonally_additive_operator disjointness_preserving_operator order_projection regular_operator vector_lattice fragment band',
#  'ideal_spaces cone_of_monotone_functions decreasing_rearrangement monotone_operator conditions_for_convexity_and_concavity_of_the_norms_and_operators associate_norms dilation_operator',
#  'initial-boundary_value_problem odd-order_evolution_equation quasilinear_evolution_equation weak_solution global_existence uniqueness large-time_decay',
#  'system_of_bodies ideal_fluid elastic_damping_device strong_solvability Cauchy_problem',
#  'surface_dynamics gradient-like_flows topological_classification Seifert_manifold',
#  'Green’s_formula transmission_problem weak_solution Lipschitz_boundaries theory_of_elasticity',
#  'auto-generator Van_der_Pol_oscillator two-frequency_oscillations asymptotic_stability_of_oscillations averaging_method',
#  'symmetric_spaces ergodic_theorems Cesáro_averages absolute_contractions norm_convergence conservative_and_strictly_conservative_operators',
#  'boundary-value_problems differential-difference_equations generalized_solution smoothness',
#  'degenerate_nonlinear_parabolic_equations conservation_laws entropy_solutions almost_periodic_functions spectrum nonlinearity-diffusivity_condition decay_property',
#  'orthogonally_additive_operator',
#  '\\(AM\\)-compact_operator positive_operator lateral_projection lateral_band',
#  '\\(C\\)-complete_vector_lattice Banach_lattice',
#  'viscoelastic_fluid boundary_value_problem hydrodynamic_system Cauchy_problem',
#  'quadratic_pencil differential_operator second_order irregular_pencil eigenvalues eigenfunction_expansion two-fold_expansion',
#  'Sturm–Liouville_operators Shrödinger_operators regular_boundary_conditions equiconvergence_of_spectral_decompositions',
#  'Lamè_system general_solution integral_representation',
#  'quasilinear_parabolic_differential–difference_equation monotone_operator strong_ellipticity',
#  'initial_boundary_value_problem differential_equation_in_Hilbert_space Cauchy_problem strong_solution spectral_problem',
#  'operator-differential_equation selfadjoint_operator operator_pencil branch_of_eigenvalues basis_property',
#  'parabolic-hyperbolic_type Gerasimov–Caputo_derivatives integral_gluing_condition existence_and_uniqueness_of_solution nonlinear_integral_equations nonlinear_loaded_term',
#  'integro-differential_equation boundary_value_problem unique_solvability forced_motion asymptotic_behavior',
#  'arithmetical_hierarchy recursion_theorem fixed-point_free_function reducibility Kolmogorov_complexity precomplete_numbering',
#  'computable_structure distinguishing_coloring index_set Boolean_algebra computable_Banach_space',
#  'theory_of_numberings analytical_hierarchy upper_semilattice Rogers_semilattice elementary_theory projective_determinacy',
#  'Butler_groups epimorphism completely_decomposable_abelian_groups',
#  'computable_model_theory primitive_recursive_function punctual_structure primitive_recursive_structure effective_algebra',
#  'numbering equivalence negative_numbering minimal_numbering admissible_structure analytic_hierarchy hyperarithmetical_sets',
#  'primitive_recursive_function computable_function algebraic_structure finitely_generated_structure locally_finite_structure',
#  'weak_o-minimality combination_of_structures almost_\\(\\omega\\)-categoricity',
#  '2-dominating_set domination_polynomial friendship_graph gear_graph helm_graph',
#  '3-colourability planar_graph computational_complexity',
#  'hereditary_ring Noetherian_ring non-primitive_ring extending_of_endomorphisms_and_automorphisms_of_modules lifting_of_endomorphisms_and_automorphisms_of_modules',
#  'logarithmic_simple_layer_potential convexity_conditions close-to-convexity_conditions star-likeness_conditions univalence_conditions',
#  'Chebyshev_set sun best_approximation max-approximation max-Chebyshev_set max-sun unique_furthest_point_problem uniquely_remotal_set',
#  'functional_equation_for_the_Riemann_zeta_function nearly_invariant_subspaces hypergeometric_functions',
#  'holomorphic_function zero_set entire_function subharmonic_function Riesz_measure',
#  '\\(\\delta\\)-subharmonic_function Jensen_measure',
#  'half-plane function_of_finite_order multiple_interpolation Nevanlinna_measure interpolation_divisor proximate_order asymptotic_inequality',
#  'boundary_value_problem Neumann_problem explicit_solution generalized_analytic_function Euler_differential_equation circular_domain',
#  'Riemann–Hilbert_problem piecewise_constant_matrix differential_equation_of_Fuchsian_type monodromy_group logarithmization_method canonical_matrix_of_the_boundary_value_problem factorization partial_indices',
#  'Caputo_fractional_derivatives non-linear_loaded_term integral_gluing_condition non-local_problem successive_approximations_method existence_and_uniqueness',
#  'differential_operator dissipative_differential_operator deficiency_indices space_of_boundary_value spectrum',
#  'differential_operator_with_involution selfadjoint_differential_operator deficiency_indices space_of_boundary_value spectrum',
#  'linear_operator_equation third_kind second_kind solution Banach_space',
#  'nonhomogeneous_subdiffusion_equation Riemann–Liouville_derivatives inverse_and_initial-boundary_value_problem determination_of_the_fractional_derivative’s_order Fourier_method',
#  'Time-fractional_subdiffusion_equation initial-boundary_value_problem Fourier_method regular_solution Sobolev_spaces',
#  'fourth_order_partial_integro-differential_equations two-point_boundary_value_problem family_of_Volterra_integro-differential_equations algorithm unique_solvability',
#  'multidimensional_loaded_mixed_type_equation_of_the_second_kind second_order seminonlocal_boundary_value_problem correctness_of_a_problem ‘‘\\(\\varepsilon\\)-regu-_larizations’’_method a_priori_estimate successive_approximation',
#  'system_of_linear_integral_equations_of_Volterra_type_of_the_second_kind solution_components absolute_integrability_on_the_half_axis quadratic_integrability_on_the_half_axis weight_functions truncating_functions sufficient_conditions_of_the_type_of_the_sign_of_the_functions',
#  'essentially_loaded_differential_equation parameterization_method algorithm',
#  'Dirichlet_problem Keldysh_problem singular_coefficients semi-infinite_parallelepiped Fourier–Bessel_series',
#  'parabolic-hyperbolic_equation initial-boundary_value_problem spectral_method unique_solvability',
#  'scattering_data expansion_formula resolvent_operator eigenvalue eigenfunction',
#  'ordinary_differential_equations nonlinear_two-point_boundary_value_problem_with_parameter isolated_solution parametrization_method solvability',
#  'Schrödinger_operators eigenvalues point_interactions two-body_Hamiltonian',
#  'boundary_value_problem system_of_ordinary_differential_equations algorithms parametrization_method necessary_and_sufficient_conditions',
#  'regularly_singular_point singular_perturbed asymptotic method_of_boundary_layer_function Roben_problem small_parameter ordinary_differential_equation',
#  'rectangular_domain loaded_equation fourth_order_derivatives spectral_method singularity existence_of_a_solution',
#  'rectangular_domain differential_equation_with_unknown_right-hand_part the_fourth_order_partial_differential_equation inverse_problem spectral_method the_uniqueness_of_the_solution the_existence_of_the_solution',
#  'optimal_control feedback Bellman_function Riccati_equation Wiener_process stochastic_system',
#  'mixed_type_equation inverse_problem parameters solvability Hilfer_operator Mittag-Leffler_function classical_solution',
#  'generalized_solution Poincare–Tricomi_type_problem degenerate_equation_of_the_second_kind energy_integral_method Green_function',
#  'integro-differential_equation singular_operators characteristic_equation integral_representation_of_manifold_solution homogeneous_equation',
#  'random_censorship product-limit relative_risk presmoothed proportional_hazards asymptotic_representation strong_consistency asymptotic_normality',
#  'Poisson_random_variable Gaussian_random_variable number_of_empty_cells',
#  'binomial_random_variable Gaussian_random_variable urn_scheme',
#  '\\(\\chi^{2}\\)-test type_I_error type_II_error',
#  'power_Garima_generated_family Garima_generated_family power_Garima-Fréchet power_Garima–Weibull power_Garima–Lindley T-X_family',
#  'zero-inflated_distribution negative_binomial_exponential_distribution count_data over-dispersion',
#  'heterogeneity_variance count_data_analysis nonparametric_mixture_models meta-analysis rare_events',
#  'stress-strength_reliability maximum-likelihood_estimator uniformly_minimum_variance_unbiased_estimator bayes_estimator prior_distribution Gibbs_sampler',
#  'probability_inequality difference_in_expected_values sequence_of_independent_nonnegative_random_variables array_of_rowwise_independent_nonnegative_random_variables almost_sure_convergence',
#  'positive_negative_binomial-Lindley_distribution zero-truncated_Poisson_distribution zero-truncated_Poisson–Lindley_distribution missing_zeros',
#  'distribution_of_Smirnov’s_statistics exponential_inequalities',
#  'discrete_laplace_distribution method_of_moments_estimator maximum_likelihood_estimator simulations',
#  'Central_limit_theorem Rate_of_convergence Random_sum Trotter-distance',
#  'confidence_estimators ratio_of_binomial_proportions direct_binomial_sampling normal_asymptotic_of_an_estimator',
#  'saddlepoint_approximations moment_generating_function branching_process cumulative_distribution_function',
#  'saddlepoint_approximations moment_generating_function survival_analysis cumulant_generating_function',
#  'point_estimation central_tendency skewed_distribution normal_approximation simulation',
#  '\\(q\\)-Meyer–König_and_Zeller_operators power_series_statistical_convergence rate_of_convergence',
#  'cross-product_ratio binomial_proportions direct_binomial_sampling_scheme inverse_binomial_sampling_scheme confidence_estimation confidence_limits asymptotic_confidence_limits delta_method normal_approximation Monte-Carlo_simulation',
#  'artificial_bee_colony_(ABC)_algorithm economic-statistical_design Hotelling’s_\\(T^{2}\\)',
#  '\\(q\\)-rung_orthopair_fuzzy_set',
#  '\\(q\\)-rung_orthopair_fuzzy_topological_space continuity',
#  'simple-direct-injective_module simple-direct-projective_module',
#  'streamer cavitation_bubble gas_dynamics interaction convergent_shock_waves bubble_deformation shock_wave_deformation',
#  'cavitation_bubble ultrasound_excitation bubble_collapse cumulative_liquid_jet boundary_element_method',
#  'nonlinear_boundary_value_problem inhomogeneous_isotropic_shell_of_Timoshenko_type equilibrium_equations generalized_solution_of_a_boundary_value_problem holomorphic_functions integral_of_Cauchy_type integral_equations operator existence_theorem',
#  'FIFO-queues mathematical_modeling data_structures markov_chains random_walks',
#  'k-meaning_logics_functions unreliable_functional_elements reliability_and_unreliability_of_circuit synthesis_of_circuits_from_unreliable_elements faults_at_the_outputs_of_elements',
#  'fractional_Laplacian fractional_Helmholtz_equation fundamental_solution factorization_technique',
#  'linear_quantization Wigner_function evolution_equation anharmonic_oscillator',
#  'diversity fading_channels Rayleigh_fading Rician_fading Two_Wave_with_Diffuse_Power_(TWDP) Multiple-Wave_with_Diffuse_Power_(MWDP)',
#  '\\(\\mathcal{H}\\)-function hypergeometric_functions special_functions bit_error_rate',
#  'reduction binary_forms hyperbolic_geometry',
#  'a_posteriori_error_estimates Cosserat_elasticity',
#  'gas_suspension shock_waves mathematical_model explicit_finite-difference_scheme_of_MacCormack',
#  'singular_continuous-time_fractional_linear_systems Caputo_fractional_derivative-integral Laurent_series Sumudu_transform',
#  'countably_connected_domain perfect_limit_point_component generalized_reduced_module Mityuk’s_radius regular_point irregular_point Wiener_criterion Brown_theorem',
#  'poe_(le)-semigroup involution right_(left)_ideal_element bi-ideal_element',
#  '\\(*\\)-right_(\\(*\\)-left)_ideal_element',
#  '\\(*\\)-bi-ideal_element regular intra-regular',
#  '\\(*\\)-regular',
#  '\\(*\\)-intra-regular',
#  '\\(*\\)-semiprime',
#  'graphene transition_metals mathematical_modeling density_functional_theory local_density_of_states',
#  'mathematical_model unsaturated_filtration dilation swelling capillary_rise',
#  'asymptotics Laplace_equation Laplace–Borel_transform manifold_with_singularity resurgent_functions',
#  'equiangular_tight_frame simplex spark',
#  'absolute_matrix_summability Hölder_inequality infinite_series Minkowski_inequality Riesz_mean summability_factors',
#  'polar_derivative complex_polynomials inequalities zeros',
#  'supercomputer workload_analysis operational_data_analytics program_performance monitoring_data job_flow_efficiency TASC',
#  'disjoint_union_of_theories Ehrenfeucht_theory distribution_of_countable_models decomposition_formula',
#  'subdirectly_irreducible_algebra congruence_lattice atom_of_congruence_lattice atomic_lattice algebra_with_operators',
#  'random_variable finite_set approximation algebraic_operations clone',
#  'ternary_semigroup interval-valued_fuzzy_soft_ideal interval-valued_fuzzy_soft_set interval-valued_fuzzy_soft_ternary_semigroup interval-valued_fuzzy_soft_bi-ideal',
#  'hyperbolic_equation differential-difference_equation classical_solution smooth_solution',
#  'porous_media disorder two-phase_flow interface numerical_simulation fingering',
#  'the_semigroup_of_shifts_on_the_half-axis singular_rank_one_perturbations',
#  'non-commutative_operator_graphs covariant_resolution_of_identity symmetric_Fock_space quantum_anticliques',
#  'Toeplitz_algebra',
#  '\\(C^{*}\\)-algebras uniform_algebras Hardy_spaces',
#  'noncommutative_Lyapunov_theorems comparison_of_states_and_normal_functionals von_Neumann_algebras',
#  '\\(JBW^{\\ast}\\)_algebras',
#  '\\(JBW^{\\ast}\\)_triples',
# ...
#  'semantic_library data_model ontologies data_sources data_integration',
#  'partial_differential_equations controlled_lexicon descriptor_word_index mathematical_thesaurus thesaurus_structure',
#  'structural_optimization nonlinear_programming sandwich_panel minimum_mass thermomechanical_loading',
#  'non-integrable_variational_forms irreversible_processes Biot_theory Darcy_hydrodynamics Navier—Stokes_hydrodynamics scale_effect',
#  'dynamical_system stability_theory stability_conditions data_assimilation_problem generalized_Kalman_filter',
#  'viscoelastic_medium_with_memory weak_solution uniform_trajectory_attractor uniform_global_attractor existence_theorem',
#  'Marcum_Q-function ℋ-function hypergeometric_functions special_functions bit_error_rate',
#  'polygamma_function zeta_function Bernoulli_polynomial Euler_polynomial Bernoulli_number Euler_number series integrals',
#  'analytical_solution second_initial-boundary_problem general_anisotropic_strip',
#  'equations_of_mathematical_physics integral_formulas average_of_differential_equations structural_functions effective_coefficients',
#  'generalized_elasticity nonsingular_solutions mechanics_of_cracks Papkovich—Neuber_representation radial_multipliers',
#  'wave_velocity eigenvalues_of_the_material_tensors anisotropy_symbol micropolar_medium tensor-block_matrix',
#  'heavy_elastica contact_problem length_of_separation non-linear_deformation',
#  'fundamental_solutions Laplace_equations harmonic_polynomials radial_multipliers inhomogeneous_media elliptic_and_ellipsoidal_inclusions heat_transfer_theory',
#  'cavitation_bubble hydrodynamic_interaction_of_bubbles bubble_deformation strong_bubble_compression',
#  'numerical_simulation Godunov_method TVD-method cavitation_bubble convergent_shock_waves bubble_deformation shock_wave_deformation liquid_tetradecane',
#  'mathematical_model conjugate_heat_and_mass_transfer film_condensation,_computing_experiment',
#  'inverse_problem horizontal_well thermohydrodynamic_studies',
#  'spherical_shell stability temperature limit_load axisymmetric_loading non-axisymmetric_loading',
#  'two-fluid_model subcooled_boiling Euler_method',
#  'bubbly_liquid multiphase_flow acoustic_waves bubbly_layer',
#  'jet_impact solid_wall jet_shape liquid_compressibility_effect shock_waves',
#  'jet_impact elastic-plastic_body von_Mises_stress body_surface_deformation',
#  'time-varying_nonlinear_systems Lipschitz_condition external_disturbances unknown_inputs observer differential_linear_matrix_inequalities',
#  'heat_transfer rotating_cylinder laminar_and_turbulent_flows',
#  'oil_reservoir non-Newtonian_oil two-phase_flow',
#  'plane cylindrical_and_spherical_waves longitudinal_and_transverse_waves porous_media capillary_pressure wetting_and_non-wetting_phases',
#  'harmonic_oscillations circular_cylinder viscous_incompressible_fluid hydrodynamic_force asymptotic_expansions',
#  'acoustic_streaming particles_drift time_splitting_method',
#  'acoustothermal_effect heat_flow resonance nonlinear_gas_oscillations open_tube',
#  'acoustic_cavitation cavitation_bubble vapor_bubble bubble_dynamics bubble_collapse converging_shock_waves',
#  'multiphase_flow decomposition_methods high_performance_computing',
#  'mathematical_model hydrodynamics_of_multiphase_environments boundary_value_problem_of_Cauchy explicit_finite-difference_scheme',
#  'actuator wing_flow_control ejector slot_suction blowing mathematical_model calculations experiment',
#  'thin-walled_elements the_system_of_scratches_in_two_normal_directions experiment tangential_and_bending_stiffnesses non-linear_theory_of_shells experimental_and_theoretical_method',
#  'films membranes thin-layer_coatings film_thickness adhesion stiffness_properties fabric_color delamination ultraviolet_radiation time_of_influence',
#  'linear_wave multifractional_medium polydispersity',
#  'containerization high_performance_computing supercomputer Docker jobs_scheduling workload_manager information_security etcd calico',
#  'AMG MPI OpenMP OpenCL CUDA',
#  'covariance_matrices Toeplitz_matrices high-performance_computing GPU',
#  'multi-agent_simulation percolation’s_cluster parallel_cluster_multiple_labeling_technique',
#  'stream multimodal_data content_delivery_network TCP UDP',
#  'computation_fluid_dynamics RANS/ILES calculation_grid grid_crushing linked_border_conditions',
#  'routing Internet global_routing_table BGP subnets IPv4 IPv6',
#  'optimization vectorization AVX-512 predicated_execution intrinsics application_performance',
#  'fuzzy_dynamical_systems Bellman_equation suboptimal_autonomous_control_law',
#  'high_performance_computing supercomputer_center English_auction distributed_computing_system',
#  'generalized_allocation_scheme Poisson_limit_theorem local_limit_theorem limit_theorem',
#  'allocation_scheme_of_distinguishing_particles_by_different_cells χ2-test S-criterion type_I_error type_II_error means_unbiased_estimator consistent_estimator',
#  'circular_field normal_field_basis fundamental_field_basis Galois_group polynomial algebraic_field_extension',
#  'Bessel_operators non-linear_Euler-Poisson-Darboux_equation Kolmogorov-Petrovsky-Piskunov_equation nonlinear_telegraph-type_equation',
#  'holomorphic_function zero_set Hausdorff_measure subharmonic_function Riesz_measure uniqueness_theorem subspherical_function',
#  'game_of_constraints evaluation_of_system_performance zero-sum_games optimization_problem penalty_method',
#  'embedding inductive_limit inductive_system injective_*-homomorphism partially_ordered_set reduced_semigroup_C*-algebra semigroup Toeplitz_algebra upward_directed_set',
#  'implicit_function continuousness zeros_of_functions',
#  'C*-algebra von_Neumann_algebra invertibility L1-nor noncommutative positive_element',
#  'continuum_mechanics aeromechanics fluid_mechanics two-phase_filtration elliptic_and_parabolic_equations modified_phase_permeability jet_flow_scheme rescaling_(upscaling)',
#  'computational_topology algorithm triangulated_manifold homology_group intersection_number',
#  'Bellman_equation Production_model stochastic_Poisson_flow identification company’s_Value Houthakker—Johansen_model unstable_demand current_assets_deficit',
#  'Shell sandwich_plate transversally_soft_core reinforcing_beams delamination geometrically_nonlinearity stress-strain_state finite_sum_method parameter_continuation_method integro-algebraic_equation two-layer_iterative_process',
#  'Grid-characteristic_method retracing ultrasound non-destructive_testing phased_array',
#  'Evolutionary_inequality parabolic_variational_inequality regularization_method semidicrete_Galerkin_scheme Rothe_scheme fully_discrete_problem',
#  'Inverse_problem Timoshenko_beam influence_function Fourier_series integral_transformation non-stationary_impact integral_equations quadrature_formulas Tikhonov_regularization.',
#  'ID_blood_flow coronary_blood_flow pacemaker tachycardia',
#  'Finite_element_method Hermite_finite_element collocation_method Reaction-Diffusion_equation',
#  'C*-algebra directed_set inductive_limit inductive_system partially_ordered_set reduced_semigroup_C*-algebra semigroup Toeplitz_algebra',
#  'Parabolic_optimal_control_problem time_fractional_derivative finite_difference_approximation iterative_method',
#  'Transient_contact_problem superposition_method adhesive_force Green_function',
#  'Mathematical_modeling grid-characteristic_method irregular_computational_meshes exploration_seismology fractured_media',
#  'Utility_function economic_indices_theory weak_separability_property',
#  'Optimal_control Mean_Field_Game numerical_approximation finite_differences economic_problems',
#  'elastic_diffusion unsteady_problems Green’s_functions integral_transformations',
#  'elastic-plastic_body UNO-scheme Godunov_scheme effectiveness_of_difference_schemes',
#  'Kirchhoff—Love_model sandwich_plate transversally_soft_core generalized_statement Gâteaux_derivative Fréchet_derivative',
#  'elastic_web constant_acceleration_movement hypergeometric_equation',
#  'dynamic_deformation_diagram friction_coefficient dry_and_viscous_friction_forces boundary_effect impact_compression form-changing strain_rate',
#  'Kolsky_method compression splitting brittle_material strain_rate stress_rate dynamic_increase_factor strength',
#  'plane_problem edge_effect boundary_layer orthotropy characteristic_equation complex_roots collocation_method numerical_implementation',
#  'boundary_element_method poroviscoelasticity boundary_integral_equation Laplace_transform Durbin’s_algorithm',
#  'Timoshenko-type_circular_cylindrical_shell superposition_method spatial_influence_function Fourier_series integral_transformations non-stationary_spatial_motion',
#  'loss_of_stability rod elastic_medium supercritical_bending nonlinear_equation',
#  'linear_viscoelasticity integral_Laplace_transform',
#  'viscoelasticity half_space Green_function generalized_convolution Laplace_transform',
#  'multi-agent_simulation percolation’s_cluster parallel_cluster_multiple_labeling_algorithm',
#  'shell layered_structure orthogonal_curvilinear_coordinates geometrically_nonlinearity finite_displacements small_strain Timoshenko_model contact_stresses kinematic_coupling_relations straight_beam plane_problem',
#  'dynamics a_beam_with_a_variable_cross-section eigenvibrations numerical_methods structural_inhomogeneity finite_element_method functionally_graded_materials',
#  'Coupled_unsteady_problems elastic_diffusion orthotropic_layer Laplace_and_Fourier_transforms bulk_Green’s_functions',
#  'Hilfer_fractional_derivative integro-partial_differential_equation mild_solution controllability',
#  'similarly_homogeneous_space completeness_radius saw-like_function vertical_ℝ-tree',
#  'unreliable_functional_element synthesis_of_reliable_circuit reliability_and_unreliability_of_circuit',
#  'Cp(X) minimal_point-separating_function_set discrete_space the_diagonal_of_a_space',
#  'Fractional_differential_equations fractional_operators monotone_sequences mixed_solutions',
#  'generalized_multiplication_operator unbounded_operator densely_defined_operator closed_operator',
#  'Generalized_Taylor_series fractional_power_series fractional_Burgers-Huxley_equations residual_power_series_method Caputo’s_fractional_derivative',
#  'partial_metric_spaces F-contraction_mappings fixed_point_theorem 47H10 54H25',
#  'Ricci_solitons gradient_Ricci_solitons normal_almost_contact_metric_manifolds',
#  'Ricci_solitons Kenmotsu generalized_D-Conformal D-homothetic Conformal shrinking expanding steady',
#  'Diffraction_problem cylindrical_waveguide generalized_functions',
#  'Homogeneous_Finsler_space naturally_reductive_homogeneous_Finsler_space exponential_metric flag_curvature bi-invariant_Riemannian_metric',
#  'Caputo_derivative fixed_point singular_fractional_integro-differential_equation existence_and_uniqueness Ulam-Hyers_stability',
#  'integro-differential_equation inverse_boundary_value_problem degenerate_kernel integral_condition unique_solvability',
#  'hyperbolic_equation Bessel_operator initial-boundary_value_problem uniqueness existence Fourier-Bessel_series uniform_convergence stability',
#  'power-associative_algebra isomorphism classification unital_algebra',
#  'ordinary_differential_equation linear_equation differential_invariant jet_space',
#  '*-open_set upper_*-continuous_multifunction lower_*-continuous_multifunction',
#  'linear_combinations idempotents nilpotents boolean_rings fields',
#  'count_data Negative_Binomial-Sushila_distribution generalized_linear_model over-dispersion Bayesian_approach',
#  'difference_equations method_of_regularization moment_problem',
#  'UP-algebra_(implicative,_comparative,_allied)_UP-filter',
#  '(M,_N)-SI-nearsemirings (M,_N)-SI-soft-ideal (M,_N)-SI-c-ideals (M,_N)-α-inclusion soft_anti-homomorphisms',
#  'logarithmic_derivative_of_rational_function simple_partial_fraction constant_electrostatic_field order_of_uniform_approximation Laguerre_polynomial exponential_function',
#  'shellable_simplicial_complex facet_ideal graded_free_resolution graded_betti_numbers betti_diagram colon_of_monomial_ideals',
#  'semiring_of_continuous_functions subalgebra lattice_of_subalgebras isomorphism Hewitt_space max-addition',
#  'Kubo–Ando_means symmetric_means norm_inequalities concavity',
#  'Balanced_signed_graphs Graph_algorithms',
#  'scalability FlowVision CFD gas_dynamics cluster supercomputer interconnect Angara',
#  'single_particle_imaging Expectation-Maximization X-ray_Free-_Electron_Laser High_Performance_Data_Analysis X-ray_Cross-Correlation_Analysis',
#  'quadratic_programming_feature_selection nonlinear_regression logistic_regression Newton_method',
#  'parallel_programming process_mapping MPI Angara interconnect',
#  'astroparticle_physics distributed_storage data_life_cycle metadata blockchain',
#  'high_performance_computing Computational_astrophysics Intel_Xeon_Phi',
#  'graph cycle graph_rearrangement operation_cost combinatorial_problem optimization_in_graphs linear_algorithm',
#  'atomistic_modelling Lennard-Jones_potential OpenSHMEM Epiphany optimization',
#  'multiscale_simulation_of_nonlinear_processes_in_gas_medium parallel_algorithms_and_software high_performance_computing',
#  'cloud_service virtualization supercomputer_modeling_in_nanotechnology_problems visualization molecular_dynamics',
#  'Spark graph_processing supervised_anomaly_detection performance_evaluation',
#  'balanced_graph_partitioning Fiduccia–Mattheyses_algorithm FM_algorithm min-cut balanced_cut',
#  'artificial_neural_network image_processing CycleGAN style_transfer segmentation',
#  'Hilbert_space von_Neumann_algebra projection measure_space commutativity convex_function operator_inequality',
#  'Cohomogeneity_two Riemannian_manifold non-positive_curvature',
#  'C*-algebra representation conditional_expectation bimodule Hilbert_module graded_system graded_C*-algebra inverse_semigroup',
#  'Korteweg-de_Vries_equation Lie_symmetries symmetry_reduction',
#  'binary_matroid splitting k-connected Γ-extension',
#  'functions_of_bounded_variation,Ostrowski_type_inequalities Riemann–Stieltjes_integral',
#  'Damped_nonlinear_Schrödinger_equation blow-up global_existence',
#  'circuit non-branching_program_with_conditional_stop_operators output_one-type_constant_faults unreliability Boolean_function',
#  'conformal_and_quasiconformal_mappings semi-linear_elliptic_equations anisotropic_and_inhomogeneous_media',
#  'Amphicheiral_knot banding achiral_hyperbolic_3-manifold chirally_cosmetic_filling chirally_cosmetic_surgery',
#  'Hölder_space non-smooth_curves non-rectifiable_curves',
#  'Conformal_radius hyperbolic_derivative α-convex_function best_dominant',
#  'Conformal_radius inner_radius_of_domain hyperbolic_derivative critical_points_of_conformal_radius Gakhov_equation',
#  'Quantum_computing online_algorithms advice_complexity quantum_vs_classical quantum_models computational_complexity',
#  'spectral_pollution generalized_spectrum proprieties_U_and_L',
#  'Kovalevskaya_integrable_case Fomenko–Zieschang_invariant marked_molecule critical_point_of_centre-centre_type',
#  'formal_group_laws height_filtration',
#  'Transformation_group Lobachevskii_plane Beltrami–Klein_model Poincarémodel 3-transitivity',
#  'Polar_derivative complex_polynomials inequalities zeros',
#  'hyperbolic_equation singular_coefficient non-local_integral_condition uniqueness Fourier–Bessel_series existence stability',
#  'weak_injective_module weak_flat_module n-weak_cotorsion_module super_finitely_presented_dimension',
#  'curvilinear_three-web boundaries_of_a_curvilinear_three-web configurations_on_a_three-web differential_invariants_of_a_3-web regular_three-web',
#  'Implicit_function continuity zeros_of_functions',
#  'Closure_operator Moore_class algebraic_lattice T0-closure_operator pre-order',
#  'linear_ordering computable_presentation low_degree strongly_η-like_linear_odering',
#  'eigenvalue eigenfunction eigenvalue_problem mesh_approximation finite_element_method',
#  'two-point_boundary_value_problem finite_element_schemes weighted_function_spaces multiplicative_and_additive-multiplicative_separation_of_singularity',
#  'nonlinear_elasticity finite_strains plasticity',
#  ...]

# %%
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import nltk
nltk.download('stopwords')


def pre_process(text):
  tokenizer = RegexpTokenizer(r'\w+')
  p_stemmer = PorterStemmer()
  stop_words = set(stopwords.words('english'))
  texts = []
  for i in text:
    raw = i.lower()
    tokens = tokenizer.tokenize(raw)
    stopped_tokens = [i for i in tokens if not i in stop_words]
    stemmed_tokens = [p_stemmer.stem(i) for i in stopped_tokens]
    texts.append(stopped_tokens)

  return texts
doc = pre_process(data['keywords'])
doc
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [['parabolic',
#   'hyperbolic_type',
#   'gerasimov',
#   'caputo_derivatives',
#   'discontinuous_gluing_condition',
#   'integral_equations'],
#  ['rearrangement_invariant_spaces',
#   'hardy_classes',
#   'grand',
#   'lebesgue_spaces',
#   'the_orlicz_spaces',
#   'boyd_indices'],
#  ['boundary_value_problem',
#   'fourier_series',
#   'eigenvalues',
#   'eigenfunctions',
#   'uniqueness_of_a_solution',
#   'existence_of_a_solution'],
#  ['schrödinger_type_equation',
#   'the_caputo_derivatives',
#   'time',
#   'dependent_source_identification_problem'],
#  ['problem_with_parameter',
#   'second_order_system_of_hyperbolic_equations',
#   'goursat_problem',
#   'solvability',
#   'algorithm'],
#  ['biharmonic_map', 'triharmonic_map', 'conformal_deformation'],
#  ['trigonometric_series',
#   'absolute_summability',
#   'measuring_set',
#   'coefficient',
#   'function'],
#  ['unit_graph',
#   'traversability',
#   'clique_number',
#   'independent_number',
#   'covering_number'],
#  ['two',
#   'body_hamiltonian',
#   'schrödinger_operators',
#   'fridrix',
#   's_model',
#   'eigenvalue',
#   'essential_spectrum',
#   'asymptotics_of_the_fredholm_determinant'],
#  ['operator_norm', 'spectral_radius', 'numerical_radius'],
#  ['acoustic_wave',
#   'liquid_droplet',
#   'vapor',
#   'gas_bubble',
#   'viscoelastic_shell',
#   'heat_and_mass_transfer'],
#  ['hydrodynamics', 'lattice_boltzmann_method'],
#  ['gauss_hypergeometric_function',
#   'hypergeometric_functions_of_three_variables',
#   'analytical_continuation_formulas',
#   'integral_representations'],
#  ['de_sitter_3',
#   'space',
#   'geodesic',
#   'magnetic_field',
#   'magnetic_trajectory',
#   'hyperbolic_quaternion',
#   'killing_vector_field'],
#  ['mathematical_model_filtration',
#   'dilation',
#   'swelling',
#   'disjoining_pressure'],
#  ['pure',
#   'injective_modules',
#   'pure',
#   'c2_modules',
#   'von_neumann',
#   '_regular_rings',
#   'pure',
#   'semisimple_rings'],
#  ['model_calibration',
#   'mle',
#   'transition_densities',
#   'heat_kernels',
#   'range',
#   'based_estimators',
#   'algorithmic_trading'],
#  ['authentication_protocols', 'processes', 'verification'],
#  ['associative_steganography',
#   'coverage_completeness_criterion',
#   'carrier_size_reduction',
#   'brute',
#   'force_attack_resistance',
#   'steganographic_durability',
#   'interference_immunity'],
#  ['marshall',
#   'olkin_distribution',
#   'sine',
#   'g_family',
#   'exponential_distribution',
#   'maximum_likelihood_estimation'],
#  ['neural_computing',
#   'neural_turing_machine',
#   'differential_neural_computer',
#   'algorithm_complexity'],
#  ['singular_coefficient',
#   'uniqueness_of_a_solution',
#   'existence_of_a_solution',
#   'singular_integral_equation',
#   'wiener',
#   'hopf_equation',
#   'index_of_equation',
#   'residue'],
#  ['optimal_quadrature_formulas',
#   'the_extremal_function',
#   'sobolev_space',
#   'optimal_coefficients',
#   'cauchy_type_singular_integral',
#   'weight_function',
#   'singular_integral_equation'],
#  ['singularity_segment',
#   'partial_differential_equation_of_parabolic_type',
#   'bisingularly_problem',
#   'singular_perturbed',
#   'asymptotic',
#   'method_of_boundary_layer_function',
#   'first_boundary_value_problem',
#   'small_parameter'],
#  ['adaptive_mesh', 'lattice_boltzmann_method', 'cuda', 'mpi'],
#  ['averaging_method', 'periodic_solution', 'non', 'integrability'],
#  ['parabolic_type',
#   'fenchel',
#   'nielsen_parameters',
#   'zero',
#   'twist_tight_flute_surface',
#   'loch_ness_monster'],
#  ['slow',
#   'fast_hamiltonian_system',
#   'averaging_method',
#   'normal_form_theory',
#   'integrable_model',
#   'improved_first_integral'],
#  ['wagner_lift',
#   'minimal_surfaces',
#   'constant_mean_curvature_surfaces',
#   'sectional_curvature'],
#  ['group_bundle',
#   'lie_groupoid',
#   'ehresmann_connection',
#   'differential_algebraic_group',
#   'ambrose',
#   'singer_theorem'],
#  ['harmonic_functions', 'liouville', 's_theorem'],
#  ['axial_principal_lines',
#   'axial_mean_lines',
#   'principal_axial_cycle',
#   'axiumbilic_point'],
#  ['curvature_line', 'umbilic_point', 'compact_surface'],
#  ['complex_analytic_vector_fields',
#   'first_integrals',
#   'essential_singularities'],
#  ['frobenius_manifolds',
#   'frobenius_algebras',
#   'manifolds_over_algebras',
#   'coalgebras'],
#  ['traveling_wave_solution',
#   'degenerate_reaction',
#   'diffusion_equations',
#   'fisher',
#   'kpp_equation',
#   'fitzhugh',
#   'nagumo_system',
#   'sharp_fronts'],
#  ['principal_lines',
#   'principal_line_fields',
#   'partially_umbilic_point',
#   'principal_configuration'],
#  ['fredholm_integro',
#   'differential_equations',
#   'weakly_singular_kernel',
#   'two',
#   'point_boundary_value_problem',
#   'fredholm_integral_equations',
#   'algorithm',
#   'unique_solvability'],
#  ['minimal_time',
#   'integral_equation',
#   'boundary_control',
#   'initial',
#   'boundary_problem',
#   'admissible_control'],
#  ['neumann_problem',
#   'multidimensional_elliptic_equations_with_several_singular_coefficients',
#   'lauricella_hypergeometric_function_of_many_variables',
#   'adjacent_and_limiting_relations',
#   'multidimensional_improper_integrals'],
#  ['two',
#   'phase_medium_dynamics',
#   'symmetry_analysis',
#   'group_classification',
#   'invariant_solution'],
#  ['degenerate_ordinary_differential_equation',
#   'boundary_value_problem',
#   'existence',
#   'uniqueness',
#   'partial_differential_equation_not_solved_for_the_derivative'],
#  ['boundary_value_problem',
#   'degenerate_equation',
#   'parabolic',
#   'hyperbolic_type',
#   'gaussian_hypergeometric_function',
#   'cauchy_problem',
#   'existence_and_uniqueness_of_the_solution',
#   'method_of_integral_equations',
#   'fractional_gerasimov',
#   'caputo_derivative'],
#  ['differential_game',
#   'life_line',
#   'pursuit',
#   'evasion',
#   'strategy',
#   'geometric_constraint'],
#  ['involution',
#   'nonlocal_operator',
#   'parabolic_equation',
#   'spectral_problem',
#   'completeness',
#   'eigenfunction',
#   'le_roy_function',
#   'hadamard',
#   'caputo_operator'],
#  ['hilfer_type_fractional_equation',
#   'nonlinear_differential_equation',
#   'mixed_problem',
#   'single',
#   'value_solvability',
#   'method_of_successive_approximations'],
#  ['dynamic_system',
#   'andronov',
#   'hopf_bifurcation',
#   'lyapunov_quantities',
#   'transcriticity',
#   'equilibrium_point',
#   'stability',
#   'reaction',
#   'diffusion_equation',
#   'cubic_nonlinearity'],
#  ['differential_equations_with_impulses',
#   'periodicity',
#   'the_critical_case_of_stability',
#   'andronov',
#   'hopf__bifurcation'],
#  ['problem_with_conditions_on_the_characteristics',
#   'system_of_hyperbolic_equation_with_piecewise',
#   'constant_argument_of_generalized_type',
#   'family_of_boundary_value_problems',
#   'new_general_solution',
#   'solvability'],
#  ['potential_operator',
#   'direct_variational_formulation',
#   'variational_principle',
#   'hamilton',
#   'ostrogradskii_equations'],
#  ['three',
#   'dimensional_tricomi_equations',
#   'linear_inverse_problem_with_a_semi',
#   'nonlocal_boundary_condition',
#   'problem_correctness',
#   'varepsilon',
#   'regularization',
#   '_method',
#   'a_priori_estimation_method',
#   'approximation_sequences_method',
#   'fourier_transforms'],
#  ['hyperbolic_equation_with_two_lines_of_degeneracy_of_the_second_kind',
#   'expansion_formula_for_the_pochhammer_symbol',
#   'appell_hypergeometric_function',
#   'generalized_solution',
#   'cauchy_problem'],
#  ['banach_spaces',
#   'fredholm_operator',
#   'generalized_solution',
#   'fundamental_operator_function'],
#  ['degenerate_type_equations',
#   'linearly_independent_solutions',
#   'generalized_hypergeometric_function',
#   'euler',
#   'bernoulli_equation',
#   'exact_solutions'],
#  ['implicit_volterra_integro',
#   'differential_equation_of_the_first_order',
#   'weak_nonlinearity',
#   'estimate_of_solutions',
#   'asymptotic_smallness_of_solutions'],
#  ['mixed_type_equation',
#   'nonlocal_equations',
#   'equation_with_degeneration',
#   'nonlocal_problem',
#   'integro',
#   'differentiation_operator',
#   'the_kilbas',
#   'saigo_function',
#   'fourier_series'],
#  ['burgers_equation',
#   'degenerating_domain',
#   'dynamic_boundary_condition',
#   'a_priori_estimate'],
#  ['essentially_loaded_differential_equation',
#   'impulse_effect',
#   'parametrization_method',
#   'algorithm'],
#  ['symptotics', 'hyperbolic_operator', 'mixed_boundary_condition'],
#  ['singularly_perturbed_system', 'parabolic_equations', 'boundary_layer'],
#  ['partial_differential_equations',
#   'pseudoparabolic_equation_of_fourth',
#   'order',
#   'semi',
#   'periodic_boundary_value_problem',
#   'algorithm',
#   'approximate_solution'],
#  ['heat_equation',
#   'degenerating_domain',
#   'laplace_transform',
#   'green',
#   's_function',
#   'fourier_method'],
#  ['equation_of_mixed_type',
#   'degeneration_of_power_type',
#   'inverse_problem',
#   'uniqueness_criterion',
#   'series',
#   'existence',
#   'stability'],
#  ['nonlinear_differential_equation', 'point_symmetries', 'exact_solutions'],
#  ['gerasimov',
#   'caputo_fractional_derivative',
#   'wright_function',
#   'mittag',
#   'leffler_function',
#   'dirac_delta_function',
#   'integral_equation'],
#  ['benney',
#   'luke_type_differential_equation',
#   'nonlinear_integral_conditions',
#   'fourier_method',
#   'absolute_and_uniform_convergence',
#   'regular_solvability'],
#  ['hamiltonian_system',
#   'stability',
#   'multiplier',
#   'small_parameter',
#   'parametric_resonance'],
#  ['integro',
#   'differential_equation',
#   'non',
#   'model_equation',
#   'characteristic_equation',
#   'two',
#   'point_special_differential_operator',
#   'unique_solvability'],
#  ['thermoviscoelastic_fluid',
#   'alpha',
#   'model',
#   'voigt_fluid',
#   'existence_theorem',
#   'topological_degree'],
#  ['lyapunov_function', 'energy_function', 'diffeomorphism', 'surface'],
#  ['orbifold',
#   'anosov_diffeomorphism',
#   'anosov_action',
#   'loretzian_metric',
#   'isometry_group'],
#  ['periodic_solutions',
#   'exponential_dichotomy',
#   'projectors',
#   'lyapunov_equation',
#   'sobolev_spaces'],
#  ['synchronization',
#   'chaos',
#   'quadratic_lyapunov_functions',
#   'frequency',
#   'domain_analysis'],
#  ['attractor', 'diffeomorphism', 'homoclinic_orbit', 'bifurcation'],
#  ['homoclinic_orbit', 'van_der_pol', 'duffing_oscillator', 'shilnikov_chaos'],
#  ['diffeomorphism',
#   '3',
#   'dimensional_manifold',
#   'expanding_attractor',
#   'embedding_of_frames'],
#  ['lorenz_system',
#   'homoclinic_orbits',
#   'periodic_motions',
#   'lorenz_attractors'],
#  ['essentially_nonlinear_differential_equations',
#   'locally_integral_manifolds',
#   'invariant_foliation',
#   'logarithmic_norms',
#   'stability'],
#  ['lorenz_attractor',
#   'pseudohyperbolicity',
#   'lyapunov_exponents',
#   'wild_hyperbolic_set'],
#  ['nonlinear_parabolic_equations_with_involution_in_the_spatial_variable',
#   'metastable_structures',
#   'center_manifold_method',
#   'galerkin_approximation_of_approximate_solutions'],
#  ['population_dynamics',
#   'two',
#   'predators',
#   'one',
#   'prey_model',
#   'bimodal_smooth_maps',
#   'schwarzian_derivative',
#   'period_doubling_bifurcations',
#   'bistability'],
#  ['differential_equation_of_neutral_type',
#   'variable_coefficients',
#   'time',
#   'varying_delay',
#   'estimates_for_solutions',
#   'stability',
#   'lyapunov',
#   'krasovskii_functional'],
#  ['model_of_immune_response_in_plants',
#   'delay_differential_equations',
#   'asymptotic_stability',
#   'estimates_of_solutions',
#   'attraction_set',
#   'lyapunov',
#   'krasovskii_functional'],
#  ['periodic_differential_operators',
#   'homogenization',
#   'operator_error_estimates',
#   'hyperbolic_equations'],
#  ['two',
#   'dimensional_diffeomorphisms',
#   'nontransverse_homoclinic_points',
#   'stable_periodic_points',
#   'characteristic_exponents'],
#  ['pandemic_uncertainty', 'vaccination', 'self', 'isolation', 'covid', '19'],
#  ['exponential_stability',
#   'lyapunov',
#   'krasovskii_functional',
#   'distributed_delay',
#   'neutral_type_equation',
#   'estimates_of_solutions'],
#  ['system_reliability',
#   'moving_extreme_ranked_set_sampling',
#   'minimax_ranked_set_sampling',
#   'exponential_distribution',
#   'relative_efficiency',
#   'ranking_errors'],
#  ['strong_law_of_large_numbers',
#   'hilbert_space',
#   'blockwise_pairwise_and_coordinatewise_negative_dependence'],
#  ['poisson',
#   'weighted_exponential_distribution',
#   'zero',
#   'truncated_distribution',
#   'maximum_likelihood_estimation'],
#  ['lambda', 'statistical_monotone'],
#  ['lambda',
#   'statistical_order_convergence',
#   'statistical_convergence',
#   'riesz_space',
#   'order_convergence'],
#  ['zero',
#   'truncated_distribution',
#   'mixed_negative_binomial_distribution',
#   'count_data',
#   'maximum_likelihood_estimation'],
#  ['mixed_negative_binomial_distribution',
#   'negative_binomial_weighted_lindley_distribution',
#   'dispersion',
#   'parameter_estimation'],
#  ['discrepancy', 'lacunary_sequence', 'law_of_the_iterated_logarithm'],
#  ['negative',
#   'binomial_random_sums',
#   'zolotarev',
#   's_probability_metric',
#   'rate_of_convergence',
#   'weak_limit_theorem'],
#  ['geometric_distribution',
#   'first_success_distribution',
#   'maximum_likelihood_estimation_method'],
#  ['combined_estimators',
#   'bias',
#   'mean_square_error',
#   'simple_random_sampling'],
#  ['community_detection',
#   'weighted_networks',
#   'bayesian_nonparametrics',
#   'mixture_models',
#   'spectral_methods'],
#  ['positive_contraction'],
#  ['p',
#   'completely_mixing',
#   'markov_operator',
#   'uniform_ergodicity',
#   'dobrushin_ergodicity_coefficient'],
#  ['bayesian_estimation',
#   'frailty',
#   'generalized_lindley_frailty',
#   'hazard_rate',
#   'mcmc',
#   'random_censoring',
#   'weibull_distribution'],
#  ['coefficient_of_variation', 'power_of_the_test', 'type_i_error_rates'],
#  ['bayesian_method',
#   'bonus',
#   'malus_system',
#   'number_of_claims',
#   'claim_size',
#   'randomized_neighborhood_search'],
#  ['statistical_modeling',
#   'normal_distribution',
#   'truncated_normal_distribution',
#   'weibull_distribution',
#   'goodness_of_fit',
#   'chi',
#   'square_test',
#   'kolmogorov',
#   'smirnov_test',
#   'aic',
#   'bic',
#   'wind_load'],
#  ['indigenous_artifacts',
#   'archaeology',
#   'clustering',
#   'statistical_analysis',
#   'carbon_dating'],
#  ['negative_binomial_distribution',
#   'lindley_distribution',
#   'cure_rate_model',
#   'survival_analysis',
#   'lifetime_distribution'],
#  ['zero',
#   'truncated',
#   'weighted_lindley_distribution',
#   'maximum_likelihood_estimation',
#   'simulation_procedures',
#   'application'],
#  ['length',
#   'biased',
#   'weibull',
#   'rayleigh_distribution',
#   'maximum_likelihood_estimation',
#   'hydrological_data'],
#  ['artificial_bee_colony_',
#   'abc',
#   '_algorithm',
#   'economic',
#   'statistical_design',
#   '_hotelling',
#   's_',
#   '2'],
#  ['monte_carlo_method',
#   'multivariate_bayesian_control_chart',
#   'variable_sample_size'],
#  ['non_response',
#   'auxiliary_variable',
#   'exponential_type_estimators',
#   'efficiency',
#   'mean_square_error'],
#  ['estimators',
#   'simple_random_sampling',
#   'mean_square_error',
#   'auxiliary_variable',
#   'study_variable'],
#  ['auxiliary_variable', 'main_variable', 'estimator', 'searls_technique'],
#  ['competing_risks',
#   'random_censoring',
#   'likelihood_ratio_statistics',
#   'local_asymptotical_normality',
#   'uniform_asymptotical_normality',
#   'asymptotic_efficiency'],
#  ['fredholm_integro',
#   'differential_equations',
#   'problem_with_integral_condition',
#   'parameter',
#   'degenerate_kernel',
#   'unique_solvability'],
#  ['accretive_differential_operator',
#   'self_adjoint_differential_operator',
#   'deficiency_index',
#   'space_of_boundary_values',
#   'spectrum'],
#  ['mixed',
#   'type_equation',
#   'fractional_derivative_in_the_sense_of_gerasimov',
#   'caputo',
#   'inverse_problem',
#   'determination_the_orders_of_fractional_derivative',
#   'one_value_solvability'],
#  ['von_neumann_algebra',
#   'algebra_of_measurable_operators',
#   'ring_isomorphisms',
#   'real_algebra_isomorphism',
#   'real_',
#   'ast',
#   'isomorphism'],
#  ['degrees', '1', 'degrees'],
#  ['hyperspace'],
#  ['aleph',
#   'space',
#   'finally_compact_space',
#   'extremally_disconnected_space',
#   'uniform_space',
#   'uniformly_connected',
#   'uniformly_paracompact',
#   'uniformly_',
#   'r',
#   'paracompact'],
#  ['2',
#   'cone_normed_space_over_the_banach_algebra',
#   'solid_cone',
#   'fixed_point'],
#  ['gauss_hypergeometric_function',
#   'integral_representation',
#   'runckel',
#   's_theorem'],
#  ['branching_random_processes',
#   'transient_phenomena',
#   'numerical_characteristics',
#   'generating_functions',
#   'estimates_of_the_rate_of_convergence',
#   'branching_processes_close_to_critical_ones'],
#  ['main_variational_problem',
#   'euler_problem',
#   'reinforced_legendre_condition',
#   'jacobi_equation',
#   'steklov_inequality',
#   'sufficient_condition_of_extremum'],
#  ['forced_oscillations',
#   'bubbly_liquid',
#   'cylindrical_path',
#   'amplitude_and_phase_frequency_characteristics'],
#  ['cubic_stochastic_operator',
#   'volterra_operator',
#   'non',
#   'volterra_operator',
#   'trajectory'],
#  ['model',
#   'three',
#   'layered_rod',
#   'loss_in_stability',
#   'middle_layer',
#   'bending_a_beam',
#   'numerical_experiment'],
#  ['conformal_radius',
#   'pre',
#   'schwarzian_derivative',
#   'subordination',
#   'convex_function',
#   'starlike_function',
#   'miller',
#   'mocanu_operator',
#   'biernacki',
#   'type_operator',
#   'gakhov_equation'],
#  ['balayage_of_measure',
#   'polynomial',
#   'logarithmic_potential',
#   'subharmonic_function',
#   'riesz_measure',
#   'weierstrass',
#   'hadamard_representation',
#   'polar_set'],
#  ['multi_criteria_optimization',
#   'optimality_criteria',
#   'parameter_analysis_of_stability',
#   'kinetic_model',
#   'catalytic_reaction'],
#  ['non',
#   'alternating_hamiltonian_lie_algebra',
#   'non',
#   'alternating_hamiltonian_form',
#   'characteristic_two'],
#  ['loaded_equation',
#   'caputo_fractional_derivative',
#   'heat_equation',
#   'volterra_integral_equation'],
#  ['cubic_stochastic_operator',
#   'volterra_operator',
#   'non',
#   'volterra_operator',
#   'regular_and_non',
#   'regular_operator'],
#  ['mean_field_game',
#   'time',
#   'fractional_derivative',
#   'non',
#   'convex_optimization',
#   'coefficient_control',
#   'finite_difference_method',
#   'stability_estimates'],
#  ['group_algebra', 'classical_ring_of_fractions', 'centrally_essential_ring'],
#  ['conformal_modulus',
#   'doubly_connected_domain',
#   'quadrilateral',
#   'quasiconformal_mapping',
#   'convergence_of_domains_to_a_kernel'],
#  ['decomposition', 'decidability', 'computational_complexity'],
#  ['boundary_value_problem_of_heat_conduction',
#   'singular_volterra_integral_equation',
#   'bessel_function',
#   'carleman',
#   'vekua_regularization_method',
#   'solvability'],
#  ['riemann_boundary_value_problem', 'picard', 'privalov_alternatives'],
#  ['fejer_sum', 'class_of_poisson_integrals', 'asymptotic_inequality'],
#  ['differential_game',
#   'langenhop_type_constraint',
#   'geometric_constraint',
#   'integral_constraint',
#   'pursuit',
#   'evasion',
#   'strategy'],
#  ['gas_cavities',
#   'grid',
#   'characteristic_method',
#   'structured_grids',
#   'numerical_modelling'],
#  ['family_of_theories', 'rank', 'degree'],
#  ['e', 'closure'],
#  ['e', 'spectrum'],
#  ['boundary_value_problem',
#   'finite_element_method',
#   'piecewise_linear_approximation',
#   'dealaunay_triangulation',
#   'recursive_algorithm'],
#  ['normal_distribution',
#   'flexibility_of_distribution',
#   'departure_from_normality',
#   'random_number_generator',
#   'maximum_likelihood_estimator',
#   'monte_carlo_method'],
#  ['laurent_series_ring', 'right_semidistributive_ring', 'semilocal_ring'],
#  ['inverse_problem',
#   'involution',
#   'nonlocal_operator',
#   'parabolic_equation',
#   'fourier_method',
#   'spectral_problem',
#   'completeness',
#   'eigenfunction'],
#  ['turning_point',
#   'inner_layer',
#   'singular_perturbed',
#   'asymptotic',
#   'method_of_boundary_layer_function',
#   'two_point_problem',
#   'small_parameter',
#   'ordinary_differential_equation'],
#  ['system_of_loaded_integro',
#   'differential_equations',
#   'involutory_transformation',
#   'boundary_value_problem',
#   'cauchy_problem',
#   'parametrization_method',
#   'unique_solvability',
#   'degenerate_kernel'],
#  ['analytic_functions',
#   'harmonic_function',
#   'quasiconformal_mapping',
#   'bohr',
#   's_inequality',
#   'subordination_and_quasisubordination'],
#  ['caliber',
#   'subtle_superextension',
#   'weight',
#   'souslin_number',
#   'subtle_complete_coupled_systems'],
#  ['absolute_permeability',
#   'heterogeneity',
#   'anisotropy',
#   'porous_media',
#   'tortuosity',
#   'kozeny',
#   'carman_equation',
#   'lattice_boltzmann_equations'],
#  ['national_research_computer_network',
#   'network_operations_center',
#   'network_management',
#   'fcaps',
#   'etom',
#   'itil',
#   'network_monitoring_and_control',
#   'network_services',
#   'software_solutions'],
#  ['national_research_computer_network_of_russia',
#   'niks',
#   'national_research_and_education_network',
#   'nrens',
#   'r',
#   'e_community',
#   'service_platform',
#   'géant',
#   'supranational_services',
#   'identity_federation',
#   'edugain',
#   'eduroam'],
#  ['supercomputers',
#   'high_performance_computing',
#   'parallel_programs_profiling',
#   'external_memory',
#   'o_operations'],
#  ['nonlinear_equations',
#   'shallow',
#   'water_icing_model',
#   'bisection_method',
#   'newton',
#   's_method',
#   'brent',
#   's_method'],
#  ['supercomputer',
#   'high_performance_computing',
#   'job_management_system',
#   'supercomputer_job_scheduling',
#   'simulation_accuracy',
#   'suppz',
#   'alea'],
#  ['digital_project',
#   'directed_acyclic_graph',
#   'internet_platform',
#   'software_platform',
#   'cloud_services',
#   'high_performance_computing'],
#  ['amg', 'setup_cost_amortization', 'non', 'steady_state', 'reuse_strategies'],
#  ['innovation',
#   'novelty',
#   'demand',
#   'implementability',
#   'additive_criterion',
#   'utility_function',
#   'additive_independence',
#   'partial_criterion'],
#  ['erosion',
#   'deposition',
#   'porous_media',
#   'experiment',
#   'mathematical_model',
#   'gpu_computations'],
#  ['supercomputer',
#   'energy_efficiency',
#   'power_consumption_profile',
#   'parallel_program',
#   'high_performance_computing_system',
#   'hpc',
#   'nas_parallel_benchmarks',
#   'intel'],
#  ['supercomputer',
#   'high_performance_computing',
#   'job_management_system',
#   'supercomputer_job_scheduling',
#   'job_runtime_prediction',
#   'suppz'],
#  ['supercomputer',
#   'unstructured_surface_computational_mesh',
#   'decomposition',
#   'domain',
#   'high',
#   'performance_computing',
#   'scaling_of_calculations'],
#  ['knots',
#   'colored_jones_polynomial',
#   'asymptotics_of_solutions_to_a_',
#   'q',
#   'recurrence_equation'],
#  ['lagrangian_system', 'oscillations', 'amplitude', 'control', 'optimization'],
#  ['coherent_state',
#   'commutation_relations',
#   'non',
#   'orthogonal_unite_decomposition'],
#  ['pressureless_gas',
#   'strong_singularities',
#   'concentration',
#   'decay',
#   'rankine',
#   'hugoniot_relations'],
#  ['numerical_analysis_and_simulation',
#   'fluid_dynamics',
#   'mechanics_of_particles_and_systems',
#   'multicomponent_multiphase_fluid_flow',
#   'multiscale_approach',
#   'natural_gas_purification',
#   'chemisorption',
#   'adsorption',
#   'catalytic_process'],
#  ['logic_circuit',
#   'self',
#   'correction',
#   'unreliable_gate',
#   'boolean_function'],
#  ['systems_of_conservation_laws',
#   'singularities',
#   'rankine',
#   'hugoniot_relations',
#   'variational_representation',
#   'weak_solutions',
#   'neural_networks'],
#  ['meixner_polynomials',
#   'hermite',
#   'padé_approximants',
#   'equilibrium_problems_for_logarithmic_potentials'],
#  ['read',
#   'once_formula',
#   'finite_field',
#   'polynomial',
#   'three',
#   'valued_logic',
#   'distribution_of_values'],
#  ['wave_equation',
#   'transparent_boundary_conditions',
#   'solution_in_circular_channel',
#   'waveguide',
#   'padé_approximation'],
#  ['hilbert_space', 'linear_operator', 'von_neumann_algebra'],
#  ['c', 'algebra', 'weight', 'trace', 'tracial_inequality'],
#  ['quantum_error_correction',
#   'non',
#   'commutative_operator_graph',
#   'qubit',
#   'quantum_oscillator',
#   'quantum_anticlique',
#   'povm'],
#  ['quantum_state_discrimination',
#   'quantum_cryptography',
#   'heterodyne_measurement'],
#  ['category_of_monoids',
#   'category_of_compact_right_topological_monoids',
#   'coproduct',
#   'exact_sequence_of_monoids',
#   'extension_of_monoids',
#   'forgetful_functor',
#   'left_adjoint_functor',
#   'stone',
#   'čech_compactification_functor'],
#  ['hilbert_space',
#   'linear_operator',
#   'projection',
#   'von_neumann_algebra',
#   'tracial_state',
#   'independence'],
#  ['discrete_dynamical_system',
#   'geometrically_integrable_map',
#   'invariant_set',
#   'periodic_orbit',
#   'coexistence_of_periods_of_periodic_orbits'],
#  ['poset_of_partial_isometries'],
#  ['ast', 'order'],
#  ['ast', 'orthogonality'],
#  ['quadratic_map', 'gradient'],
#  ['text', 'k3', '_surface'],
#  ['random_field',
#   'gibbs_random_field',
#   'correlation_functions',
#   'specification',
#   'p',
#   'function',
#   'q',
#   'function'],
#  ['free_product_of_algebras',
#   'commutator_relation',
#   'mutually_unbiased_bases',
#   'abelianization'],
#  ['learning_theory',
#   'statistical_mechanics',
#   'evolution_theory',
#   'functional_programming'],
#  ['dynamical_behavior_of_stochastic_systems',
#   'classification_problem',
#   'diagnostics',
#   'qubit_system',
#   'quantum_system',
#   'markovian_process'],
#  ['quantum_measurement_channel',
#   'classical_capacity',
#   'entanglement',
#   'assisted_capacity'],
#  ['reduced_semigroup_',
#   'c',
#   'algebra',
#   'free_banach_module',
#   'graded_',
#   'c',
#   'algebra',
#   'cyclic_banach_module',
#   'topological_isomorphism_of_banach_modules'],
#  ['quantum_technologies',
#   'distributed_system_with_diffusion',
#   'quantum_control',
#   'laser',
#   'assisted_isotope_separation',
#   'molybdenum_isotopes'],
#  ['open_quantum_system',
#   'two_qubits',
#   'optimal_quantum_control',
#   'coherent_control',
#   'incoherent_control'],
#  ['random_linear_operator',
#   'random_operator_valued_process',
#   'law_of_large_numbers',
#   'central_limit_theorem'],
#  ['gibbs_process', 'uniqueness', 'kirkwood', 'salsburg_equations'],
#  ['spectral_decomposition_of_a_state',
#   'quantum_channel',
#   'holevo_capacity',
#   'output_entropy',
#   'entropy_exchange',
#   'mutual_information',
#   'coherent_information',
#   'squashed_entanglement_of_a_channel'],
#  ['open_quantum_system',
#   'master_equation',
#   'markovianity',
#   'rotating_wave_approximation'],
#  ['inverse_problem',
#   'nonlinear_filtration',
#   'bottomhole_pressure',
#   'well_testing',
#   'stress_sensitive_fractured_porous_reservoir',
#   'pressure_dependent_permeability'],
#  ['dynamics_of_gas_bubbles',
#   'cluster_of_bubbles',
#   'hydrodynamic_interaction_of_bubbles',
#   'radial_oscillations_of_bubbles',
#   'particle_model_of_bubble_interaction'],
#  ['unsteady_heat_transfer',
#   'enclosing_structures',
#   'radiation',
#   'convective_heat_transfer',
#   'numerical_methods',
#   'computer_simulation'],
#  ['inverse_problem',
#   'navier',
#   'stokes_equations',
#   'rans',
#   'methods',
#   'high',
#   'lift_devices',
#   'multi',
#   'element_airfoil',
#   'target_pressure_distribution'],
#  ['harmonic_oscillations',
#   'circular_cylinder',
#   'steady_streaming',
#   'viscous_incompressible_fluid',
#   'asymptotic_expansions'],
#  ['three', 'phase_flow', 'inverse_problem', 'permeability_identification'],
#  ['waves', 'bubbly_liquid', 'heat_and_mass_transfer'],
#  ['airfoil', 'flap', 'slat_systems', 'fowler_flap', 'neural_net'],
#  ['radial_oscillations',
#   'gas_bubbles',
#   'viscoelastic_shell_and_liquid',
#   'maxwell',
#   's_model',
#   'kelvin',
#   'voigt_model'],
#  ['thermoacoustic_waves',
#   'heat_transfer',
#   'natural_convection',
#   'finite',
#   'volume_method'],
#  ['resonance', 'nonlinear_gas_oscillations', 'closed_tube'],
#  ['acoustic_wave', 'reflection_coefficient', 'polydisperse_inclusions'],
#  ['liquid_drop_impingement',
#   'curved_solid_surface',
#   'shock_wave',
#   'initial_jetless_stage'],
#  ['porous_medium',
#   'self',
#   'similar_solution',
#   'phase_transition',
#   'extended_area_of_gas_hydrate_formation'],
#  ['cavitation_bubble',
#   'ultrasound_excitation',
#   'bubble_collapse_near_a_wall',
#   'cumulative_liquid_jet',
#   'boundary_element_method'],
#  ['bubble_dynamics',
#   'boundary_element_method',
#   'boundary_integral_equation_method'],
#  ['continuos_system',
#   'lipschitz_condition',
#   'uncertain_disturbances',
#   'discrete_measurements',
#   'observer_design'],
#  ['oblate_ellipsoidal_shell',
#   'bending',
#   'temperature',
#   'limit_load',
#   'axisymmetric_load'],
#  ['couette',
#   'taylor',
#   'poiseuille_flow',
#   'torque',
#   'numerical_simulation',
#   'two',
#   'phase_flow',
#   'annular_channel'],
#  ['downhole_heater',
#   'radial_fluid_flow',
#   'reservoir_temperature',
#   'thermal_dispersion',
#   'peclet_number',
#   'well_productivity'],
#  ['gas_hydrates', 'mathematical_model', 'algorithm', 'sampling'],
#  ['filtration',
#   'numerical_solution',
#   'formation_of_gas_hydrate',
#   'zonal_heterogeneous_porous_reservoir'],
#  ['orr',
#   'sommerfeld_equation',
#   'thermoviscous_fluid',
#   'eigenvalues',
#   'eigenfunctions',
#   'reynolds_number',
#   'aqueous_solution_of_propylene_glycol',
#   'heat',
#   'exchanger'],
#  ['plane',
#   'cylindrical_and_spherical_waves',
#   'longitudinal_and_transverse_waves',
#   'porous_media',
#   'capillary_pressure',
#   'three_phase_fluid'],
#  ['gas_suspension',
#   'acoustic_waves',
#   'impedance',
#   'reflection_coefficient',
#   'refraction_coefficient'],
#  ['acoustic_cavitation',
#   'bubble_dynamics',
#   'bubble_collapse',
#   'converging_shock_waves'],
#  ['multiphase_nonisothermal_flow',
#   'decomposition_methods',
#   'high_performance_computing'],
#  ['quasi',
#   'hydrostatic_approximation',
#   'atmospheric_modelling',
#   'linear_instability',
#   'shortwave_perturbation',
#   'pseudo_viscosity'],
#  ['a_toroidal_shell',
#   'a_local_deepening_on_the_inner_surface',
#   'a_spline_option_of_the_finite_element_method',
#   'stress_intensity'],
#  ['three',
#   'dimensional_finite_elements',
#   'two',
#   'dimensional_finite_elements',
#   'complex_geometry',
#   'parametrization'],
#  ['incompressible_flow',
#   'bifurcation_theory',
#   'homotopy_method',
#   'stability',
#   'nonlinearity',
#   'gradient_fluid'],
#  ['nonlinear_partial_equations',
#   'sobolev',
#   'type_equations',
#   'exact_solutions'],
#  ['ontology_design', 'word2vec', 'semantic_relationships', 'subject_ontology'],
#  ['space',
#   'time_continuum',
#   'variational_models',
#   'non',
#   'integrable_variational_forms',
#   'irreversible_processes',
#   'coupled_hydrodynamics_and_heat_transfer',
#   'darcy_equations',
#   'brinkman_equations'],
#  ['data_assimilation_problem',
#   'da_problem',
#   'generalized_kalman_filter_method',
#   'ornstein',
#   'uhlenbeck_process'],
#  ['fading_channels',
#   'multiple',
#   'wave_with_diffuse_power_',
#   'mwdp',
#   'two_wave_with_diffuse_power_',
#   'twdp'],
#  ['mathcal',
#   'b',
#   'function',
#   'special_functions',
#   'hypergeometric_functions',
#   'lauricella_hypergeometric_function',
#   'bit_error_rate'],
#  ['problem_of_sturm',
#   'liuvill',
#   'second_order_differential_equations',
#   'equations_with_variable_coefficients',
#   'integral_formulas'],
#  ['heat_equation', 'spectral_problem'],
#  ['thermoelasticity',
#   'thermal_conductivity',
#   'coupled_effects',
#   'generalized_papkovich',
#   'neuber_representation',
#   'fundamental_solutions'],
#  ['incompatible_deformations',
#   'residual_stresses',
#   'body_manifold',
#   'non',
#   'euclidean_geometry',
#   'material_connections',
#   'cartan_moving_frame',
#   'curvature',
#   'torsion',
#   'nonmetricity',
#   'contorsion',
#   'surface_growth'],
#  ['biharmonic_operator',
#   'boundary_value_problems',
#   'scattering_model',
#   'variational_method'],
#  ['biharmonic_operator',
#   'steklov_and_steklov',
#   'type_boundary_conditions',
#   'dirichlet_integral',
#   'weighted_spaces'],
#  ['micropolar_theory',
#   'theory_of_thin_bodies',
#   'legendre_and_chebyshev_polynomials',
#   'multilayer_thin_body',
#   'tensor',
#   'operator_of_stress_and_couple_stress',
#   'tensor',
#   'block_matrix_operator',
#   'decomposition_of_initial',
#   'boundary_value_problems'],
#  ['3d_printing',
#   'selective_laser_melting',
#   'additive_manufacturing',
#   'concentrated_load',
#   'moving_load',
#   'heat_flux',
#   'transient_function'],
#  ['semantic_library',
#   'subject_domain',
#   'ontology',
#   'thesaurus',
#   'data_integration',
#   'data_preprocessing',
#   'data_cleaning',
#   'data_model'],
#  ['electroelasticity',
#   'surface_shear_wave',
#   'gradient_effects',
#   'attenuation'],
#  ['gradient_elasticity',
#   'papkovich',
#   'neuber_representation',
#   'fourth',
#   'order_equations',
#   'fundamental_solutions_of_laplace_and_helmholtz_equations',
#   'green',
#   's_integral_formula',
#   'trefftz_method',
#   'bubnov',
#   'galerkin_projection_method'],
#  ['cavitation_bubble_dynamics',
#   'bubble_collapse',
#   'non',
#   'spherical_bubble',
#   'convergent_shock_waves',
#   'non',
#   'spherical_shock_waves',
#   'wide',
#   'range_equations_of_state',
#   'direct_numerical_simulation',
#   'godunov_method'],
#  ['filtration',
#   'gas_hydrate',
#   'methane',
#   'carbon_dioxide',
#   'replacement',
#   'mathematical_modeling'],
#  ['cavitational_flows', 'nonlinear_functional', 'global_minimization'],
#  ['porous_medium', 'layer', 'waveguide', 'wave_propagation'],
#  ['boundary_value_problem',
#   'circular_plate',
#   'boundary_conditions',
#   'average_pressure',
#   'linear_bending',
#   'nonlinear_bending'],
#  ['circular_cylinder',
#   'cross_flow',
#   'channel',
#   'vortical_patterns_in_wake',
#   'direct_numerical_simulation',
#   'fourier_transform',
#   'transition_to_turbulence',
#   'spectral_analysis'],
#  ['elasticity',
#   'creep',
#   'plasticity',
#   'viscosity',
#   'thermal_conductivity',
#   'large_strains'],
#  ['fiber_reinforced_plastic',
#   'fiber',
#   'bundle_of_fibers',
#   'epoxy',
#   'specimen',
#   'cross',
#   'ply_lay',
#   'tension',
#   'compression',
#   'shear',
#   'linearized_equations',
#   'buckling_modes',
#   'finite_sum_method',
#   'integrating_matrices',
#   'ultimate_stress'],
#  ['multilayer_plate',
#   'discrete_structural_model',
#   'internal_friction_of_the_material',
#   'kelvin',
#   'voigt_model',
#   'generalized_helmholtz_equation',
#   'free_and_forced_vibrations',
#   'complex_vibration_frequency',
#   'sound_insulation_parameter',
#   'sound_pressure'],
#  ['oil_reservoir',
#   'well_patterns',
#   'two',
#   'phase_flow',
#   'viscosity_ratio',
#   'fixed_streamtube_model',
#   'low',
#   'dimensional_problems',
#   'high',
#   'speed_models',
#   'high',
#   'resolution_models'],
#  ['orthotropic_materials',
#   'integration_of_equations_equilibrium',
#   'displacements',
#   'stresses'],
#  ['mathematical_modeling',
#   'finite_deformations',
#   'constitutive_equations',
#   'phase_transition',
#   'relaxation_transition',
#   'shape_memory',
#   'boundary_value_problems',
#   'finite_element_method'],
#  ['multiplicative_decomposition_of_deformation_gradient_tensor',
#   'rigid_moving_coordinate_system',
#   'constitutive_mathematical_models',
#   'geometrical_nonlinearity'],
#  ['large_elastoplastic_deformations', 'contact_interaction'],
#  ['elastic_diffusion',
#   'coupled_problem',
#   'unsteady_problem',
#   'integral_transform',
#   'multicomponent_continuum',
#   'kirchhoff',
#   'love_plate',
#   'green',
#   's_function'],
#  ['work',
#   'stealing_balancers',
#   'work',
#   'stealing_deques',
#   'data_structures',
#   'absorbing_markov_chains',
#   'random_walks'],
#  ['algowiki',
#   'problems',
#   'methods',
#   'algorithms',
#   'implementations',
#   'information_graph',
#   'parallel_structure',
#   'supercomputer'],
#  ['global_optimization',
#   'non',
#   'convex_constraints',
#   'mixed',
#   'integer_problems',
#   'local_tuning',
#   'parallel_algorithms'],
#  ['ultrasound_tomography',
#   'wave_simulation',
#   'multi',
#   'core_processor',
#   'gpu'],
#  ['thin_films',
#   'molecular_dynamics',
#   'silicon_dioxide_films',
#   'laser_pulses',
#   'heat_transfer',
#   'stresses',
#   'laser_induced_damage'],
#  ['dark_states',
#   'supercomputer',
#   'tavis',
#   'cummings_model',
#   'graph_algorithms'],
#  ['thesaurus', 'embedding', 'lexical_relations', 'senses'],
#  ['supercomputing',
#   'high',
#   'performance_computing',
#   'workload_analysis',
#   'efficiency',
#   'data_analysis',
#   'monitoring_data',
#   'system_software'],
#  ['high',
#   'performance_computing',
#   'parallel_computing',
#   'performance_analysis',
#   'performance_variability',
#   'supercomputers'],
#  ['drug_discovery',
#   'docking',
#   'quantum_chemistry',
#   'inhibitors',
#   'plpro',
#   'sars',
#   'cov',
#   '2',
#   'covid',
#   '19',
#   'cadd'],
#  ['large',
#   'eddy_simulation',
#   'subgrid_models',
#   'boundary_layer_turbulence',
#   'evening_transition',
#   'computational_performance'],
#  ['hpc', 'mpi', 'parallel', 'clustering', 'error_messages'],
#  ['multidimensional_integration',
#   'multivariate_integration',
#   'numerical_integration',
#   'sampling_point',
#   'tensor_train',
#   'tt',
#   'format'],
#  ['open_quantum_systems', 'integer_programming', 'machine_learning'],
#  ['differential_equation',
#   'fractional_de',
#   '_rivative',
#   'fractional_caputo_derivative',
#   'stability',
#   'uniform_convergence_of_a_locally_one',
#   'dimensional_difference_scheme',
#   'convection',
#   'diffusion_equation',
#   'locally_one',
#   'dimensional_scheme'],
#  ['parabolic_variational_inequality',
#   'obstacle_problem',
#   'penalty_method',
#   'regularization_method',
#   'accuracy_estimate'],
#  ['numerical_simulation',
#   'elastic_waves',
#   'grid',
#   'characteristic_method',
#   'discontinuous_galerkin_method',
#   'unstructured_grids',
#   'regular_grids'],
#  ['scientific_computing',
#   'non',
#   'uniform_grid',
#   'difference_maximum_principle',
#   'monotone_difference_scheme',
#   'regularization_principle',
#   'convection',
#   'diffusion_equation',
#   'third_boundary_value_problem',
#   'two',
#   'side_estimate'],
#  ['symmetric_linear_multistep_methods',
#   'periodical_initial_value_problem',
#   'stability_polynomial',
#   'interval_of_periodicity'],
#  ['mean_field_games',
#   'additional_inequality',
#   'fokker',
#   'planck',
#   'kolmogorov_equation',
#   'hamilton',
#   'jacobi',
#   'bellman_equation',
#   'discrete_approximation',
#   'numerical_solution'],
#  ['eigenvibration',
#   'bar',
#   'mechanical_resonator',
#   'eigenvalue',
#   'eigenfunction',
#   'eigenvalue_problem',
#   'ordinary_differential_equation',
#   'finite_element_method'],
#  ['quasilinear_parabolic_problem',
#   'time',
#   'fractional_derivative',
#   'regularized_scheme',
#   'stability',
#   'accuracy'],
#  ['circular_cylinder',
#   'cross_flow',
#   'channel',
#   'gap_between_cylinder_and_wall',
#   'large',
#   'scale_vortex',
#   'transition_to_turbulence',
#   'spiral_tornado',
#   'like_motion'],
#  ['machine_learning',
#   'convolutional_neural_networks',
#   'mathematical_modeling',
#   'grid',
#   'characteristic_method',
#   'exploration_seismology',
#   'inverse_problems',
#   'fractured_media'],
#  ['modified_ramsey_model',
#   'consumer_behavior',
#   'mean_field_games',
#   'optimal_control',
#   'numerical_solution'],
#  ['schwartz_algebra',
#   'entire_function',
#   'slowly_decreasing_function',
#   'distribution_of_zero_set'],
#  ['hilbert_spaces',
#   'entire_functions',
#   'unconditional_bases',
#   'reproducing_kernels'],
#  ['sturm',
#   'liouville_equation',
#   'trivial_monodromy',
#   'spectral_instability',
#   'spectrum_localization'],
#  ['meromorphic_function', 'nevanlinna_characteristic', 'subharmonic_function'],
#  ['delta', 'subharmonic_function', 'riesz_measure'],
#  ['series_of_exponential_monomials',
#   'weight_space',
#   'analytic_continuation',
#   'condensation_index'],
#  ['differential_operators',
#   'closed_sets',
#   'time_scales',
#   'inverse_spectral_problems'],
#  ['liouville_lattice',
#   'soliton',
#   'breather',
#   'instanton',
#   'linear_spectrum',
#   'homoclinic_orbit',
#   'periodic_solutions',
#   'c',
#   'integrability'],
#  ['elliptic_pseudo',
#   'differential_equation',
#   'boundary_value_problem',
#   'singular_domain',
#   'asymptotic_behavior'],
#  ['family_of_boundary_value_problems',
#   'integro',
#   'differential_equations_of_mixed_type',
#   'parametrization_method',
#   'solvability'],
#  ['degenerate_fractional_optimal_control_problem',
#   'initial_value_problem',
#   'caputo_fractional_derivative',
#   'lebesgue_spaces',
#   'pontryagin',
#   's_maximum_principle'],
#  ['inhomogeneous_chain_of_harmonic_oscillators',
#   'cauchy_problem',
#   'random_initial_data',
#   'space',
#   'time_statistical_solutions',
#   'weak_convergence_of_measures'],
#  ['anomalous_diffusion',
#   'integro',
#   'differential_equation',
#   'gerasimov',
#   'caputo_fractional_derivative',
#   'laplace_transform',
#   'fourier_transform',
#   'convolution_theorem',
#   'explicit_solution'],
#  ['parabolic',
#   'hyperbolic_type_equation',
#   'integral_condition',
#   'cauchy_problem',
#   'first_boundary_value_problem'],
#  ['discrete_bilaplacian', 'eigenvalue', 'asymptotics', 'essential_spectrum'],
#  ['discrete_schrödinger_operator',
#   'quasi',
#   'momentum',
#   'essential_spectrum',
#   'eigenvalue',
#   'determinant'],
#  ['three_body_hamiltonian',
#   'discrete_schrödinger_operator',
#   'short',
#   'range_pair_potentials',
#   'eigenvalues',
#   'essential_spectrum'],
#  ['boundary_value_problem',
#   'third',
#   'order_partial_integro',
#   'differential_equation',
#   'existence_and_uniqueness_of_solution',
#   'degenerate_kernel',
#   'multiple_characteristics',
#   'green',
#   's_function'],
#  ['infinite_waveguide',
#   'metal_diaphragm',
#   'rectangular_resonator',
#   'eigen_frequency'],
#  ['diffraction_problem',
#   'method_of_moments',
#   'cuda_technology',
#   'rwg_functions'],
#  ['antenna',
#   'chiral_metamaterial',
#   'hypersingularity',
#   'method_integral_equations',
#   'current_density'],
#  ['electromagnetic_wave_diffraction',
#   'integral_equations',
#   'collocation_method',
#   'chebyshev_polynomials'],
#  ['boundary_integral_equations',
#   'numerical_methods',
#   'computational_electrodynamics',
#   'mathematical_modeling_of_antennas'],
#  ['electromagnetic_wave',
#   'scattering',
#   'axial',
#   'symmetric_body',
#   'non',
#   'coordinate_boundary'],
#  ['electromagnetic_wave', 'diffraction', 'generalized_function'],
#  ['lasing_eigenvalue_problem', 'set_of_muller_boundary_integral_equations'],
#  ['nonstationary_electrodynamics',
#   'integral_equations',
#   'media_without_dispersion',
#   'effective_algorithms'],
#  ['non',
#   'polarized_electromagnetic_waves',
#   'inhomogeneous_waveguide',
#   'complex_permittivity',
#   'dielectric_with_losses',
#   'non',
#   'linear_eigenvalue_problem',
#   'maxwell_equations',
#   'operator',
#   'function',
#   'spectrum'],
#  ['equation_of_mixed_parabolic',
#   'hyperbolic_type',
#   'inverse_problem',
#   'uniqueness',
#   'series',
#   'small_denominators',
#   'existence'],
#  ['surface_wave',
#   'dielectric_layer',
#   'inhomogeneous_layer',
#   'eigenvalue_problem',
#   'maxwell',
#   's_equations',
#   'operator_pencil',
#   'spectrum',
#   'double_completeness'],
#  ['non',
#   'polarized_electromagnetic_waves',
#   'anisotropic_waveguide',
#   'non',
#   'linear_eigenvalue_problem',
#   'maxwell',
#   's_equations',
#   'operator',
#   'function',
#   'spectrum'],
#  ['fluid_filtration',
#   'darcy',
#   'brinkman_law',
#   'integral_equations',
#   'potential_theory',
#   'piecewise',
#   'constant_approximation',
#   'collocation_method'],
#  ['orthogonally_additive_operator',
#   'disjointness_preserving_operator',
#   'order_projection',
#   'regular_operator',
#   'vector_lattice',
#   'fragment',
#   'band'],
#  ['ideal_spaces',
#   'cone_of_monotone_functions',
#   'decreasing_rearrangement',
#   'monotone_operator',
#   'conditions_for_convexity_and_concavity_of_the_norms_and_operators',
#   'associate_norms',
#   'dilation_operator'],
#  ['initial',
#   'boundary_value_problem',
#   'odd',
#   'order_evolution_equation',
#   'quasilinear_evolution_equation',
#   'weak_solution',
#   'global_existence',
#   'uniqueness',
#   'large',
#   'time_decay'],
#  ['system_of_bodies',
#   'ideal_fluid',
#   'elastic_damping_device',
#   'strong_solvability',
#   'cauchy_problem'],
#  ['surface_dynamics',
#   'gradient',
#   'like_flows',
#   'topological_classification',
#   'seifert_manifold'],
#  ['nonlinear_parabolic_equations_with_involution_in_the_spatial_variable',
#   'metastable_structures',
#   'center_manifold_method',
#   'galerkin_approximation_of_approximate_solutions'],
#  ['green',
#   's_formula',
#   'transmission_problem',
#   'weak_solution',
#   'lipschitz_boundaries',
#   'theory_of_elasticity'],
#  ['auto',
#   'generator',
#   'van_der_pol_oscillator',
#   'two',
#   'frequency_oscillations',
#   'asymptotic_stability_of_oscillations',
#   'averaging_method'],
#  ['symmetric_spaces',
#   'ergodic_theorems',
#   'cesáro_averages',
#   'absolute_contractions',
#   'norm_convergence',
#   'conservative_and_strictly_conservative_operators'],
#  ['boundary',
#   'value_problems',
#   'differential',
#   'difference_equations',
#   'generalized_solution',
#   'smoothness'],
#  ['degenerate_nonlinear_parabolic_equations',
#   'conservation_laws',
#   'entropy_solutions',
#   'almost_periodic_functions',
#   'spectrum',
#   'nonlinearity',
#   'diffusivity_condition',
#   'decay_property'],
#  ['orthogonally_additive_operator'],
#  ['compact_operator',
#   'positive_operator',
#   'lateral_projection',
#   'lateral_band'],
#  ['c', 'complete_vector_lattice', 'banach_lattice'],
#  ['viscoelastic_fluid',
#   'boundary_value_problem',
#   'hydrodynamic_system',
#   'cauchy_problem'],
#  ['quadratic_pencil',
#   'differential_operator',
#   'second_order',
#   'irregular_pencil',
#   'eigenvalues',
#   'eigenfunction_expansion',
#   'two',
#   'fold_expansion'],
#  ['sturm',
#   'liouville_operators',
#   'shrödinger_operators',
#   'regular_boundary_conditions',
#   'equiconvergence_of_spectral_decompositions'],
#  ['lamè_system', 'general_solution', 'integral_representation'],
#  ['quasilinear_parabolic_differential',
#   'difference_equation',
#   'monotone_operator',
#   'strong_ellipticity'],
#  ['initial_boundary_value_problem',
#   'differential_equation_in_hilbert_space',
#   'cauchy_problem',
#   'strong_solution',
#   'spectral_problem'],
#  ['operator',
#   'differential_equation',
#   'selfadjoint_operator',
#   'operator_pencil',
#   'branch_of_eigenvalues',
#   'basis_property'],
#  ['parabolic',
#   'hyperbolic_type',
#   'gerasimov',
#   'caputo_derivatives',
#   'integral_gluing_condition',
#   'existence_and_uniqueness_of_solution',
#   'nonlinear_integral_equations',
#   'nonlinear_loaded_term'],
#  ['integro',
#   'differential_equation',
#   'boundary_value_problem',
#   'unique_solvability',
#   'forced_motion',
#   'asymptotic_behavior'],
#  ['arithmetical_hierarchy',
#   'recursion_theorem',
#   'fixed',
#   'point_free_function',
#   'reducibility',
#   'kolmogorov_complexity',
#   'precomplete_numbering'],
#  ['computable_structure',
#   'distinguishing_coloring',
#   'index_set',
#   'boolean_algebra',
#   'computable_banach_space'],
#  ['theory_of_numberings',
#   'analytical_hierarchy',
#   'upper_semilattice',
#   'rogers_semilattice',
#   'elementary_theory',
#   'projective_determinacy'],
#  ['butler_groups', 'epimorphism', 'completely_decomposable_abelian_groups'],
#  ['computable_model_theory',
#   'primitive_recursive_function',
#   'punctual_structure',
#   'primitive_recursive_structure',
#   'effective_algebra'],
#  ['numbering',
#   'equivalence',
#   'negative_numbering',
#   'minimal_numbering',
#   'admissible_structure',
#   'analytic_hierarchy',
#   'hyperarithmetical_sets'],
#  ['primitive_recursive_function',
#   'computable_function',
#   'algebraic_structure',
#   'finitely_generated_structure',
#   'locally_finite_structure'],
#  ['weak_o',
#   'minimality',
#   'combination_of_structures',
#   'almost_',
#   'omega',
#   'categoricity'],
#  ['2',
#   'dominating_set',
#   'domination_polynomial',
#   'friendship_graph',
#   'gear_graph',
#   'helm_graph'],
#  ['3', 'colourability', 'planar_graph', 'computational_complexity'],
#  ['hereditary_ring',
#   'noetherian_ring',
#   'non',
#   'primitive_ring',
#   'extending_of_endomorphisms_and_automorphisms_of_modules',
#   'lifting_of_endomorphisms_and_automorphisms_of_modules'],
#  ['logarithmic_simple_layer_potential',
#   'convexity_conditions',
#   'close',
#   'convexity_conditions',
#   'star',
#   'likeness_conditions',
#   'univalence_conditions'],
#  ['chebyshev_set',
#   'sun',
#   'best_approximation',
#   'max',
#   'approximation',
#   'max',
#   'chebyshev_set',
#   'max',
#   'sun',
#   'unique_furthest_point_problem',
#   'uniquely_remotal_set'],
#  ['functional_equation_for_the_riemann_zeta_function',
#   'nearly_invariant_subspaces',
#   'hypergeometric_functions'],
#  ['holomorphic_function',
#   'zero_set',
#   'entire_function',
#   'subharmonic_function',
#   'riesz_measure'],
#  ['delta', 'subharmonic_function', 'jensen_measure'],
#  ['half',
#   'plane',
#   'function_of_finite_order',
#   'multiple_interpolation',
#   'nevanlinna_measure',
#   'interpolation_divisor',
#   'proximate_order',
#   'asymptotic_inequality'],
#  ['boundary_value_problem',
#   'neumann_problem',
#   'explicit_solution',
#   'generalized_analytic_function',
#   'euler_differential_equation',
#   'circular_domain'],
#  ['riemann',
#   'hilbert_problem',
#   'piecewise_constant_matrix',
#   'differential_equation_of_fuchsian_type',
#   'monodromy_group',
#   'logarithmization_method',
#   'canonical_matrix_of_the_boundary_value_problem',
#   'factorization',
#   'partial_indices'],
#  ['caputo_fractional_derivatives',
#   'non',
#   'linear_loaded_term',
#   'integral_gluing_condition',
#   'non',
#   'local_problem',
#   'successive_approximations_method',
# ...
#  ['mathematical_model',
#   'conjugate_heat_and_mass_transfer',
#   'film_condensation',
#   '_computing_experiment'],
#  ['inverse_problem', 'horizontal_well', 'thermohydrodynamic_studies'],
#  ['three', 'phase_flow', 'inverse_problem', 'permeability_identification'],
#  ['waves', 'bubbly_liquid', 'heat_and_mass_transfer'],
#  ['spherical_shell',
#   'stability',
#   'temperature',
#   'limit_load',
#   'axisymmetric_loading',
#   'non',
#   'axisymmetric_loading'],
#  ['acoustic_waves',
#   'polidispersity',
#   'phase_transformations',
#   'dispersion_relation',
#   'distribution_function'],
#  ['two', 'fluid_model', 'subcooled_boiling', 'euler_method'],
#  ['bubbly_liquid', 'multiphase_flow', 'acoustic_waves', 'bubbly_layer'],
#  ['jet_impact',
#   'solid_wall',
#   'jet_shape',
#   'liquid_compressibility_effect',
#   'shock_waves'],
#  ['jet_impact',
#   'elastic',
#   'plastic_body',
#   'von_mises_stress',
#   'body_surface_deformation'],
#  ['time',
#   'varying_nonlinear_systems',
#   'lipschitz_condition',
#   'external_disturbances',
#   'unknown_inputs',
#   'observer',
#   'differential_linear_matrix_inequalities'],
#  ['heat_transfer', 'rotating_cylinder', 'laminar_and_turbulent_flows'],
#  ['oil_reservoir', 'non', 'newtonian_oil', 'two', 'phase_flow'],
#  ['plane',
#   'cylindrical_and_spherical_waves',
#   'longitudinal_and_transverse_waves',
#   'porous_media',
#   'capillary_pressure',
#   'wetting_and_non',
#   'wetting_phases'],
#  ['harmonic_oscillations',
#   'circular_cylinder',
#   'viscous_incompressible_fluid',
#   'hydrodynamic_force',
#   'asymptotic_expansions'],
#  ['acoustic_streaming', 'particles_drift', 'time_splitting_method'],
#  ['acoustothermal_effect',
#   'heat_flow',
#   'resonance',
#   'nonlinear_gas_oscillations',
#   'open_tube'],
#  ['acoustic_cavitation',
#   'cavitation_bubble',
#   'vapor_bubble',
#   'bubble_dynamics',
#   'bubble_collapse',
#   'converging_shock_waves'],
#  ['multiphase_flow', 'decomposition_methods', 'high_performance_computing'],
#  ['mathematical_model',
#   'hydrodynamics_of_multiphase_environments',
#   'boundary_value_problem_of_cauchy',
#   'explicit_finite',
#   'difference_scheme'],
#  ['actuator',
#   'wing_flow_control',
#   'ejector',
#   'slot_suction',
#   'blowing',
#   'mathematical_model',
#   'calculations',
#   'experiment'],
#  ['thin',
#   'walled_elements',
#   'the_system_of_scratches_in_two_normal_directions',
#   'experiment',
#   'tangential_and_bending_stiffnesses',
#   'non',
#   'linear_theory_of_shells',
#   'experimental_and_theoretical_method'],
#  ['films',
#   'membranes',
#   'thin',
#   'layer_coatings',
#   'film_thickness',
#   'adhesion',
#   'stiffness_properties',
#   'fabric_color',
#   'delamination',
#   'ultraviolet_radiation',
#   'time_of_influence'],
#  ['linear_wave', 'multifractional_medium', 'polydispersity'],
#  ['containerization',
#   'high_performance_computing',
#   'supercomputer',
#   'docker',
#   'jobs_scheduling',
#   'workload_manager',
#   'information_security',
#   'etcd',
#   'calico'],
#  ['amg', 'mpi', 'openmp', 'opencl', 'cuda'],
#  ['covariance_matrices',
#   'toeplitz_matrices',
#   'high',
#   'performance_computing',
#   'gpu'],
#  ['multi',
#   'agent_simulation',
#   'percolation',
#   's_cluster',
#   'parallel_cluster_multiple_labeling_technique'],
#  ['stream', 'multimodal_data', 'content_delivery_network', 'tcp', 'udp'],
#  ['computation_fluid_dynamics',
#   'rans',
#   'iles',
#   'calculation_grid',
#   'grid_crushing',
#   'linked_border_conditions'],
#  ['routing',
#   'internet',
#   'global_routing_table',
#   'bgp',
#   'subnets',
#   'ipv4',
#   'ipv6'],
#  ['optimization',
#   'vectorization',
#   'avx',
#   '512',
#   'predicated_execution',
#   'intrinsics',
#   'application_performance'],
#  ['fuzzy_dynamical_systems',
#   'bellman_equation',
#   'suboptimal_autonomous_control_law'],
#  ['high_performance_computing',
#   'supercomputer_center',
#   'english_auction',
#   'distributed_computing_system'],
#  ['generalized_allocation_scheme',
#   'poisson_limit_theorem',
#   'local_limit_theorem',
#   'limit_theorem'],
#  ['allocation_scheme_of_distinguishing_particles_by_different_cells',
#   'χ2',
#   'test',
#   'criterion',
#   'type_i_error',
#   'type_ii_error',
#   'means_unbiased_estimator',
#   'consistent_estimator'],
#  ['circular_field',
#   'normal_field_basis',
#   'fundamental_field_basis',
#   'galois_group',
#   'polynomial',
#   'algebraic_field_extension'],
#  ['bessel_operators',
#   'non',
#   'linear_euler',
#   'poisson',
#   'darboux_equation',
#   'kolmogorov',
#   'petrovsky',
#   'piskunov_equation',
#   'nonlinear_telegraph',
#   'type_equation'],
#  ['holomorphic_function',
#   'zero_set',
#   'hausdorff_measure',
#   'subharmonic_function',
#   'riesz_measure',
#   'uniqueness_theorem',
#   'subspherical_function'],
#  ['game_of_constraints',
#   'evaluation_of_system_performance',
#   'zero',
#   'sum_games',
#   'optimization_problem',
#   'penalty_method'],
#  ['embedding',
#   'inductive_limit',
#   'inductive_system',
#   'injective_',
#   'homomorphism',
#   'partially_ordered_set',
#   'reduced_semigroup_c',
#   'algebra',
#   'semigroup',
#   'toeplitz_algebra',
#   'upward_directed_set'],
#  ['implicit_function', 'continuousness', 'zeros_of_functions'],
#  ['c',
#   'algebra',
#   'von_neumann_algebra',
#   'invertibility',
#   'l1',
#   'noncommutative',
#   'positive_element'],
#  ['continuum_mechanics',
#   'aeromechanics',
#   'fluid_mechanics',
#   'two',
#   'phase_filtration',
#   'elliptic_and_parabolic_equations',
#   'modified_phase_permeability',
#   'jet_flow_scheme',
#   'rescaling_',
#   'upscaling'],
#  ['computational_topology',
#   'algorithm',
#   'triangulated_manifold',
#   'homology_group',
#   'intersection_number'],
#  ['bellman_equation',
#   'production_model',
#   'stochastic_poisson_flow',
#   'identification',
#   'company',
#   's_value',
#   'houthakker',
#   'johansen_model',
#   'unstable_demand',
#   'current_assets_deficit'],
#  ['shell',
#   'sandwich_plate',
#   'transversally_soft_core',
#   'reinforcing_beams',
#   'delamination',
#   'geometrically_nonlinearity',
#   'stress',
#   'strain_state',
#   'finite_sum_method',
#   'parameter_continuation_method',
#   'integro',
#   'algebraic_equation',
#   'two',
#   'layer_iterative_process'],
#  ['grid',
#   'characteristic_method',
#   'retracing',
#   'ultrasound',
#   'non',
#   'destructive_testing',
#   'phased_array'],
#  ['evolutionary_inequality',
#   'parabolic_variational_inequality',
#   'regularization_method',
#   'semidicrete_galerkin_scheme',
#   'rothe_scheme',
#   'fully_discrete_problem'],
#  ['inverse_problem',
#   'timoshenko_beam',
#   'influence_function',
#   'fourier_series',
#   'integral_transformation',
#   'non',
#   'stationary_impact',
#   'integral_equations',
#   'quadrature_formulas',
#   'tikhonov_regularization'],
#  ['id_blood_flow', 'coronary_blood_flow', 'pacemaker', 'tachycardia'],
#  ['finite_element_method',
#   'hermite_finite_element',
#   'collocation_method',
#   'reaction',
#   'diffusion_equation'],
#  ['c',
#   'algebra',
#   'directed_set',
#   'inductive_limit',
#   'inductive_system',
#   'partially_ordered_set',
#   'reduced_semigroup_c',
#   'algebra',
#   'semigroup',
#   'toeplitz_algebra'],
#  ['parabolic_optimal_control_problem',
#   'time_fractional_derivative',
#   'finite_difference_approximation',
#   'iterative_method'],
#  ['transient_contact_problem',
#   'superposition_method',
#   'adhesive_force',
#   'green_function'],
#  ['mathematical_modeling',
#   'grid',
#   'characteristic_method',
#   'irregular_computational_meshes',
#   'exploration_seismology',
#   'fractured_media'],
#  ['utility_function', 'economic_indices_theory', 'weak_separability_property'],
#  ['optimal_control',
#   'mean_field_game',
#   'numerical_approximation',
#   'finite_differences',
#   'economic_problems'],
#  ['elastic_diffusion',
#   'unsteady_problems',
#   'green',
#   's_functions',
#   'integral_transformations'],
#  ['elastic',
#   'plastic_body',
#   'uno',
#   'scheme',
#   'godunov_scheme',
#   'effectiveness_of_difference_schemes'],
#  ['kirchhoff',
#   'love_model',
#   'sandwich_plate',
#   'transversally_soft_core',
#   'generalized_statement',
#   'gâteaux_derivative',
#   'fréchet_derivative'],
#  ['elastic_web', 'constant_acceleration_movement', 'hypergeometric_equation'],
#  ['dynamic_deformation_diagram',
#   'friction_coefficient',
#   'dry_and_viscous_friction_forces',
#   'boundary_effect',
#   'impact_compression',
#   'form',
#   'changing',
#   'strain_rate'],
#  ['kolsky_method',
#   'compression',
#   'splitting',
#   'brittle_material',
#   'strain_rate',
#   'stress_rate',
#   'dynamic_increase_factor',
#   'strength'],
#  ['plane_problem',
#   'edge_effect',
#   'boundary_layer',
#   'orthotropy',
#   'characteristic_equation',
#   'complex_roots',
#   'collocation_method',
#   'numerical_implementation'],
#  ['boundary_element_method',
#   'poroviscoelasticity',
#   'boundary_integral_equation',
#   'laplace_transform',
#   'durbin',
#   's_algorithm'],
#  ['timoshenko',
#   'type_circular_cylindrical_shell',
#   'superposition_method',
#   'spatial_influence_function',
#   'fourier_series',
#   'integral_transformations',
#   'non',
#   'stationary_spatial_motion'],
#  ['loss_of_stability',
#   'rod',
#   'elastic_medium',
#   'supercritical_bending',
#   'nonlinear_equation'],
#  ['linear_viscoelasticity', 'integral_laplace_transform'],
#  ['viscoelasticity',
#   'half_space',
#   'green_function',
#   'generalized_convolution',
#   'laplace_transform'],
#  ['multi',
#   'agent_simulation',
#   'percolation',
#   's_cluster',
#   'parallel_cluster_multiple_labeling_algorithm'],
#  ['shell',
#   'layered_structure',
#   'orthogonal_curvilinear_coordinates',
#   'geometrically_nonlinearity',
#   'finite_displacements',
#   'small_strain',
#   'timoshenko_model',
#   'contact_stresses',
#   'kinematic_coupling_relations',
#   'straight_beam',
#   'plane_problem'],
#  ['dynamics',
#   'a_beam_with_a_variable_cross',
#   'section',
#   'eigenvibrations',
#   'numerical_methods',
#   'structural_inhomogeneity',
#   'finite_element_method',
#   'functionally_graded_materials'],
#  ['coupled_unsteady_problems',
#   'elastic_diffusion',
#   'orthotropic_layer',
#   'laplace_and_fourier_transforms',
#   'bulk_green',
#   's_functions'],
#  ['hilfer_fractional_derivative',
#   'integro',
#   'partial_differential_equation',
#   'mild_solution',
#   'controllability'],
#  ['similarly_homogeneous_space',
#   'completeness_radius',
#   'saw',
#   'like_function',
#   'vertical_ℝ',
#   'tree'],
#  ['unreliable_functional_element',
#   'synthesis_of_reliable_circuit',
#   'reliability_and_unreliability_of_circuit'],
#  ['cp',
#   'x',
#   'minimal_point',
#   'separating_function_set',
#   'discrete_space',
#   'the_diagonal_of_a_space'],
#  ['fractional_differential_equations',
#   'fractional_operators',
#   'monotone_sequences',
#   'mixed_solutions'],
#  ['generalized_multiplication_operator',
#   'unbounded_operator',
#   'densely_defined_operator',
#   'closed_operator'],
#  ['generalized_taylor_series',
#   'fractional_power_series',
#   'fractional_burgers',
#   'huxley_equations',
#   'residual_power_series_method',
#   'caputo',
#   's_fractional_derivative'],
#  ['partial_metric_spaces',
#   'f',
#   'contraction_mappings',
#   'fixed_point_theorem',
#   '47h10',
#   '54h25'],
#  ['ricci_solitons',
#   'gradient_ricci_solitons',
#   'normal_almost_contact_metric_manifolds'],
#  ['ricci_solitons',
#   'kenmotsu',
#   'generalized_d',
#   'conformal',
#   'homothetic',
#   'conformal',
#   'shrinking',
#   'expanding',
#   'steady'],
#  ['diffraction_problem', 'cylindrical_waveguide', 'generalized_functions'],
#  ['homogeneous_finsler_space',
#   'naturally_reductive_homogeneous_finsler_space',
#   'exponential_metric',
#   'flag_curvature',
#   'bi',
#   'invariant_riemannian_metric'],
#  ['caputo_derivative',
#   'fixed_point',
#   'singular_fractional_integro',
#   'differential_equation',
#   'existence_and_uniqueness',
#   'ulam',
#   'hyers_stability'],
#  ['integro',
#   'differential_equation',
#   'inverse_boundary_value_problem',
#   'degenerate_kernel',
#   'integral_condition',
#   'unique_solvability'],
#  ['hyperbolic_equation',
#   'bessel_operator',
#   'initial',
#   'boundary_value_problem',
#   'uniqueness',
#   'existence',
#   'fourier',
#   'bessel_series',
#   'uniform_convergence',
#   'stability'],
#  ['power',
#   'associative_algebra',
#   'isomorphism',
#   'classification',
#   'unital_algebra'],
#  ['ordinary_differential_equation',
#   'linear_equation',
#   'differential_invariant',
#   'jet_space'],
#  ['open_set',
#   'upper_',
#   'continuous_multifunction',
#   'lower_',
#   'continuous_multifunction'],
#  ['linear_combinations',
#   'idempotents',
#   'nilpotents',
#   'boolean_rings',
#   'fields'],
#  ['count_data',
#   'negative_binomial',
#   'sushila_distribution',
#   'generalized_linear_model',
#   'dispersion',
#   'bayesian_approach'],
#  ['difference_equations', 'method_of_regularization', 'moment_problem'],
#  ['algebra_', 'implicative', '_comparative', '_allied', '_up', 'filter'],
#  ['_n',
#   'si',
#   'nearsemirings',
#   '_n',
#   'si',
#   'soft',
#   'ideal',
#   '_n',
#   'si',
#   'c',
#   'ideals',
#   '_n',
#   'α',
#   'inclusion',
#   'soft_anti',
#   'homomorphisms'],
#  ['logarithmic_derivative_of_rational_function',
#   'simple_partial_fraction',
#   'constant_electrostatic_field',
#   'order_of_uniform_approximation',
#   'laguerre_polynomial',
#   'exponential_function'],
#  ['shellable_simplicial_complex',
#   'facet_ideal',
#   'graded_free_resolution',
#   'graded_betti_numbers',
#   'betti_diagram',
#   'colon_of_monomial_ideals'],
#  ['semiring_of_continuous_functions',
#   'subalgebra',
#   'lattice_of_subalgebras',
#   'isomorphism',
#   'hewitt_space',
#   'max',
#   'addition'],
#  ['kubo', 'ando_means', 'symmetric_means', 'norm_inequalities', 'concavity'],
#  ['balanced_signed_graphs', 'graph_algorithms'],
#  ['scalability',
#   'flowvision',
#   'cfd',
#   'gas_dynamics',
#   'cluster',
#   'supercomputer',
#   'interconnect',
#   'angara'],
#  ['single_particle_imaging',
#   'expectation',
#   'maximization',
#   'x',
#   'ray_free',
#   '_electron_laser',
#   'high_performance_data_analysis',
#   'x',
#   'ray_cross',
#   'correlation_analysis'],
#  ['quadratic_programming_feature_selection',
#   'nonlinear_regression',
#   'logistic_regression',
#   'newton_method'],
#  ['parallel_programming', 'process_mapping', 'mpi', 'angara', 'interconnect'],
#  ['astroparticle_physics',
#   'distributed_storage',
#   'data_life_cycle',
#   'metadata',
#   'blockchain'],
#  ['high_performance_computing',
#   'computational_astrophysics',
#   'intel_xeon_phi'],
#  ['graph',
#   'cycle',
#   'graph_rearrangement',
#   'operation_cost',
#   'combinatorial_problem',
#   'optimization_in_graphs',
#   'linear_algorithm'],
#  ['atomistic_modelling',
#   'lennard',
#   'jones_potential',
#   'openshmem',
#   'epiphany',
#   'optimization'],
#  ['multiscale_simulation_of_nonlinear_processes_in_gas_medium',
#   'parallel_algorithms_and_software',
#   'high_performance_computing'],
#  ['cloud_service',
#   'virtualization',
#   'supercomputer_modeling_in_nanotechnology_problems',
#   'visualization',
#   'molecular_dynamics'],
#  ['spark',
#   'graph_processing',
#   'supervised_anomaly_detection',
#   'performance_evaluation'],
#  ['balanced_graph_partitioning',
#   'fiduccia',
#   'mattheyses_algorithm',
#   'fm_algorithm',
#   'min',
#   'cut',
#   'balanced_cut'],
#  ['artificial_neural_network',
#   'image_processing',
#   'cyclegan',
#   'style_transfer',
#   'segmentation'],
#  ['hilbert_space',
#   'von_neumann_algebra',
#   'projection',
#   'measure_space',
#   'commutativity',
#   'convex_function',
#   'operator_inequality'],
#  ['cohomogeneity_two', 'riemannian_manifold', 'non', 'positive_curvature'],
#  ['c',
#   'algebra',
#   'representation',
#   'conditional_expectation',
#   'bimodule',
#   'hilbert_module',
#   'graded_system',
#   'graded_c',
#   'algebra',
#   'inverse_semigroup'],
#  ['korteweg', 'de_vries_equation', 'lie_symmetries', 'symmetry_reduction'],
#  ['binary_matroid', 'splitting', 'k', 'connected', 'γ', 'extension'],
#  ['functions_of_bounded_variation',
#   'ostrowski_type_inequalities',
#   'riemann',
#   'stieltjes_integral'],
#  ['damped_nonlinear_schrödinger_equation', 'blow', 'global_existence'],
#  ['circuit',
#   'non',
#   'branching_program_with_conditional_stop_operators',
#   'output_one',
#   'type_constant_faults',
#   'unreliability',
#   'boolean_function'],
#  ['conformal_and_quasiconformal_mappings',
#   'semi',
#   'linear_elliptic_equations',
#   'anisotropic_and_inhomogeneous_media'],
#  ['amphicheiral_knot',
#   'banding',
#   'achiral_hyperbolic_3',
#   'manifold',
#   'chirally_cosmetic_filling',
#   'chirally_cosmetic_surgery'],
#  ['hölder_space', 'non', 'smooth_curves', 'non', 'rectifiable_curves'],
#  ['conformal_radius',
#   'hyperbolic_derivative',
#   'α',
#   'convex_function',
#   'best_dominant'],
#  ...]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vector = TfidfVectorizer()

# %%
X =vector.fit_transform(doc)
print(X)
# Out:
#   (0, 2630)	0.3553435377722737
#   (0, 1414)	0.46250080227033863
#   (0, 649)	0.4382517149455751
#   (0, 2185)	0.4077014779196955
#   (0, 2466)	0.3967976263589244
#   (0, 3868)	0.37959262509703723
#   (1, 590)	0.4117671835067655
#   (1, 5406)	0.4117671835067655
#   (1, 2925)	0.3901780784904868
#   (1, 2243)	0.4117671835067655
#   (1, 2310)	0.4117671835067655
#   (1, 4437)	0.4117671835067655
#   (2, 1747)	0.44012605178465763
#   (2, 5673)	0.4581106815899699
#   (2, 1551)	0.44012605178465763
#   (2, 1556)	0.39679350993828993
#   (2, 1950)	0.38284354729506187
#   (2, 576)	0.3141630934076388
#   (3, 1283)	0.5250749911554526
#   (3, 5454)	0.41579894298723746
#   (3, 5389)	0.5250749911554526
#   (3, 4730)	0.5250749911554526
#   (4, 186)	0.3843737082957127
#   (4, 5010)	0.3843737082957127
#   (4, 2216)	0.46721313403432324
#   :	:
#   (1673, 5921)	0.513109854428187
#   (1673, 5671)	0.38764896856638725
#   (1674, 4661)	0.4472135954999579
#   (1674, 2023)	0.4472135954999579
#   (1674, 4260)	0.4472135954999579
#   (1674, 3224)	0.4472135954999579
#   (1674, 2107)	0.4472135954999579
#   (1675, 5661)	0.40824829046386296
#   (1675, 1797)	0.40824829046386296
#   (1675, 1452)	0.40824829046386296
#   (1675, 5082)	0.40824829046386296
#   (1675, 1525)	0.40824829046386296
#   (1675, 2327)	0.40824829046386296
#   (1676, 4391)	0.5
#   (1676, 3922)	0.5
#   (1676, 4383)	0.5
#   (1676, 207)	0.5
#   (1677, 3431)	0.5362398485349962
#   (1677, 1408)	0.5362398485349962
#   (1677, 1042)	0.43194600131058986
#   (1677, 2851)	0.4881765066429566
#   (1678, 4451)	0.5303391391066145
#   (1678, 3153)	0.5025332628080059
#   (1678, 1296)	0.48280467960822143
#   (1678, 1221)	0.48280467960822143

# %%
from sklearn.decomposition import TruncatedSVD
lsa = TruncatedSVD(n_components=10,n_iter=100)
tfidf_lsa = lsa.fit_transform(X)

# %%
lsa.fit(X)
# Out:
# TruncatedSVD(n_components=10, n_iter=100)

# %%
terms = vector.get_feature_names()
components = lsa.components_[1]
idx_top_terms = sorted(range(len(components)), key=lambda k: components[k])
print("10 highest-weighted terms in concept 1:")
for t in idx_top_terms[:10]:
    print(" - %s : %0.02f"%(terms[t], t))
# Out:
# 10 highest-weighted terms in concept 1:
#  - non : 3602.00
#  - maxwell : 3245.00
#  - s_equations : 4638.00
#  - linear_eigenvalue_problem : 3011.00
#  - operator : 3773.00
#  - polarized_electromagnetic_waves : 4081.00
#  - spectrum : 5053.00
#  - function : 2029.00
#  - commutative_operator_graphs : 837.00
#  - quantum_anticliques : 4286.00
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
for i,comp in enumerate(lsa.components_):
    termsInComp = zip(terms,comp)
    sortedterms = sorted(termsInComp, key=lambda x: x[1],reverse=True)[:10]
    print("Concept %d:" % i)
    for term in sortedterms:
        print(term[0])
    print(" ")
# Out:
# Concept 0:
# non
# spectrum
# function
# maxwell
# s_equations
# linear_eigenvalue_problem
# operator
# polarized_electromagnetic_waves
# inhomogeneous_waveguide
# commutative_operator_graphs
#
# Concept 1:
# hilbert_space
# projection
# von_neumann_algebra
# linear_operator
# algebra
# idempotent
# operator_inequality
# trace
# commutativity
# unitary_operator
#
# Concept 2:
# eigenvalue
# finite_element_method
# eigenfunction
# eigenvalue_problem
# ordinary_differential_equation
# nonlinear_eigenvalue_problem
# eigenvibration
# positive_eigenfunction
# boundary_value_problem
# beam
#
# Concept 3:
# boundary_value_problem
# uniqueness
# differential_equation
# existence
# integro
# small_denominators
# series
# unique_solvability
# initial
# inverse_problem
#
# Concept 4:
# differential_equation
# integro
# degenerate_kernel
# solvability
# unique_solvability
# characteristic_equation
# two
# singular_integral_operator
# inverse_boundary_value_problem
# spectral_parameters
#
# Concept 5:
# algebra
# toeplitz_algebra
# function
# spectrum
# reduced_semigroup_c
# inductive_limit
# partially_ordered_set
# inverse_semigroup
# semigroup
# partial_isometry
#
# Concept 6:
# function
# spectrum
# hypergeometric_functions
# bit_error_rate
# special_functions
# mathcal
# maxwell
# s_equations
# operator
# linear_eigenvalue_problem
#
# Concept 7:
# inequalities
# zeros
# polar_derivative
# polynomials
# complex_polynomials
# operators
# s_theorem
# maximum_modulus
# rouche
# extremal_problems
#
# Concept 8:
# supercomputer
# high_performance_computing
# two
# high
# inverse_problem
# characteristic_method
# grid
# job_management_system
# performance_computing
# suppz
#
# Concept 9:
# differential_invariant
# jet_space
# symmetry_algebra
# high_performance_computing
# supercomputer
# ordinary_differential_equation
# high
# two
# thermodynamical_state
# characteristic_method

# %%
from scipy.spatial import distance

query_idx = 400

query_features = tfidf_lsa[query_idx]
distances = [ distance.cosine(query_features, feat) for feat in tfidf_lsa ]
idx_closest = sorted(range(len(distances)), key=lambda k: distances[k])[1:]

query_doc = doc[query_idx]
return_doc = doc[idx_closest[0]]
print("Document's keywords:\n %s \nMost similar keywords to previous document:\n %s" %(query_doc, return_doc))
# Out:
# Document's keywords:
#  saddlepoint_approximations moment_generating_function branching_process cumulative_distribution_function
# Most similar keywords to previous document:
#  saddlepoint_approximations moment_generating_function survival_analysis cumulant_generating_function
